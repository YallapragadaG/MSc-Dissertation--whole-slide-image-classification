# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip drive/My\ Drive/Fold1.zip
#installing relevent modules for resnet34 model
# !pip install git+https://github.com/qubvel/classification_models.git
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/05322-18627.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/16853-07096.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/45237-05322.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/10644-20401.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/45237-30158.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/32819-19514.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/54107-11531.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/39915-24836.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/12418-24836.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/32819-21288.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/64751-20401.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/58542-18627.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/76282-10644.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/37254-19514.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/08870-23062.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/75395-09757.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/24836-31932.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/36367-24836.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/69186-24836.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/65638-19514.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/49672-12418.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/76282-12418.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/73621-27497.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/09757-19514.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/07096-17740.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/58542-13305.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/47898-31045.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/29271-15966.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/42576-25723.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/17740-25723.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/71847-28384.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/16853-26610.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/07096-16853.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/17740-11531.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/21288-07096.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/70073-25723.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/56768-14192.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/23062-28384.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/27497-27497.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/60316-18627.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/52333-13305.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/59429-18627.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/33706-18627.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/54994-14192.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/47011-07096.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/25723-28384.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/47898-30158.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/09757-21288.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/68299-23949.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/40802-04435.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/46124-07983.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/46124-12418.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/30158-29271.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/19514-12418.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/19514-07983.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/13305-24836.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/61203-20401.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/25723-29271.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/55881-15079.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/07983-22175.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/45237-27497.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/19514-08870.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/17740-26610.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/42576-26610.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/43463-28384.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/16853-25723.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/62090-17740.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/26610-31932.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/53220-09757.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/54994-10644.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/52333-34593.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/62090-16853.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/14192-25723.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/23062-29271.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/07983-20401.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/02661-18627.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/70073-26610.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/71847-29271.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/40802-23062.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/48785-09757.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/63864-22175.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/62977-21288.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/14192-23949.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/17740-24836.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/38141-20401.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/43463-07983.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/52333-12418.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/16853-23949.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/52333-07983.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/41689-05322.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/70073-24836.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/16853-27497.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/72734-28384.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/46124-29271.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/38141-22175.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/57655-13305.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/16853-09757.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/63864-20401.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/48785-11531.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/62977-19514.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/43463-08870.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/53220-11531.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/52333-08870.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/19514-28384.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/34593-17740.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/44350-09757.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/23062-08870.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/03548-16853.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/25723-12418.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/78056-11531.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/19514-29271.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/03548-17740.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/36367-20401.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/33706-21288.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/46124-28384.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/34593-23949.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/47011-30158.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/49672-06209.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/60316-19514.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/36367-22175.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/14192-24836.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/47011-31045.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/59429-19514.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/21288-30158.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/29271-16853.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/33706-19514.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/16853-24836.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/24836-28384.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/69186-22175.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/70073-23949.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/23062-12418.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/39915-22175.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/17740-27497.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/12418-22175.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-UT-A88D-01Z-00-DX2.AE0B6725-767E-4E45-A34D-3BC8F1CBE923.svs/44350-27497.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/30906-13635.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/18180-12726.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/25452-13635.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/25452-11817.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/102717-10908.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/104535-09090.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/22725-09999.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/30906-11817.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/28179-09090.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/27270-09999.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/19089-08181.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/14544-06363.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/104535-15453.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/19998-09090.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/28179-15453.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/86355-03636.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/106353-09999.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/99990-09999.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/23634-10908.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/26361-10908.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/113625-13635.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/113625-11817.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/17271-10908.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/109989-17271.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/21816-07272.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/110898-14544.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/103626-09090.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/102717-13635.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/07272-05454.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/115443-11817.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/88173-05454.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/109989-14544.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/09090-06363.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/07272-06363.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/31815-14544.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/30906-10908.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/25452-10908.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/115443-13635.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/108171-08181.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/19089-07272.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/102717-11817.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/23634-11817.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/26361-11817.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/110898-12726.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/24543-09999.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/31815-12726.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/109989-12726.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/113625-10908.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/21816-08181.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/26361-13635.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/17271-11817.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/23634-13635.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/17271-09090.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/19089-12726.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/115443-15453.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/18180-08181.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/16362-08181.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/108171-17271.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/111807-14544.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/19998-10908.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/23634-09090.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/32724-12726.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/26361-09090.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/103626-13635.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/102717-09090.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/10908-06363.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/26361-15453.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/104535-10908.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/28179-10908.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/111807-12726.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/32724-14544.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/92718-06363.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/103626-11817.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/108171-12726.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/19998-13635.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/107262-09999.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/109080-09999.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/17271-06363.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/18180-07272.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/25452-15453.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/23634-06363.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/19998-11817.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/100899-09999.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/87264-05454.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/104535-11817.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/108171-14544.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/30906-09090.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/28179-11817.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/21816-12726.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/25452-09090.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/103626-10908.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/113625-15453.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/28179-13635.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/104535-13635.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/13635-06363.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/103626-09999.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/100899-10908.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/98172-07272.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/96354-08181.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/24543-15453.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/22725-06363.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/99081-07272.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/97263-07272.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/20907-12726.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/24543-09090.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/109080-16362.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/107262-16362.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/15453-09090.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/109080-10908.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/107262-10908.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/112716-14544.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/100899-13635.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/101808-14544.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/105444-08181.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/94536-06363.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/96354-07272.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/106353-15453.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/100899-11817.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/97263-08181.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/99081-08181.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/29088-12726.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/104535-09999.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/22725-09090.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/28179-09999.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/27270-09090.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/106353-09090.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/107262-13635.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/112716-12726.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/109080-13635.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/99990-09090.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/19998-09999.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/27270-15453.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/24543-06363.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/91809-06363.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/101808-12726.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/15453-06363.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/85446-03636.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/29997-08181.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/29088-14544.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/107262-11817.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/109080-11817.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/06363-05454.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/08181-05454.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/106353-13635.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/107262-09090.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/109080-09090.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/99990-13635.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/113625-09999.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/06363-06363.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/08181-06363.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/89082-04545.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/24543-10908.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/106353-11817.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/99990-11817.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/22725-11817.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/30906-09999.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/27270-11817.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/100899-09090.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/25452-09999.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/101808-07272.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/107262-15453.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/20907-08181.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/109080-15453.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/27270-13635.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/22725-13635.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/29997-14544.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/97263-12726.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/17271-09999.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/99081-12726.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/29088-08181.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/98172-12726.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/24543-13635.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/106353-16362.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/24543-11817.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/33633-14544.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/99990-10908.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/106353-10908.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/95445-06363.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/105444-12726.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/23634-09999.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/114534-12726.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/26361-09999.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/90900-06363.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/29997-12726.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/102717-09999.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/22725-10908.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/27270-10908.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/90900-05454.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/27270-16362.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/105444-14544.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/101808-08181.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/33633-12726.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/114534-14544.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/20907-07272.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/101808-09090.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/20907-06363.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/105444-10908.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/29088-15453.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/106353-12726.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/99990-12726.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/105444-16362.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/27270-14544.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/11817-06363.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/100899-07272.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/98172-10908.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/99081-10908.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/97263-10908.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/95445-07272.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/18180-09999.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/16362-09999.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/33633-10908.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/99990-14544.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/106353-14544.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/29088-09090.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/112716-15453.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/27270-12726.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/22725-12726.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/29997-10908.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/98172-13635.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/109989-09999.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/105444-11817.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/31815-09999.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/24543-12726.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/110898-09999.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/114534-11817.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/20907-09090.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/99081-13635.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/97263-11817.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/99081-11817.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/114534-13635.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/100899-08181.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/98172-11817.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/105444-13635.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/24543-14544.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/33633-11817.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/95445-08181.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/89082-05454.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/29997-13635.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/29997-11817.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/107262-08181.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/33633-13635.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/15453-07272.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/29088-10908.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/105444-15453.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/114534-15453.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/29997-09090.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-SC-A6LM-01A-01-TSA.820FD6FE-015D-4904-A467-A9CE0276BE88.svs/106353-08181.jpg
# ...
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/04430-06202.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/62906-08860.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/70880-14176.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/65564-15062.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/14176-11518.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/70880-17720.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/10632-09746.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/14176-13290.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/65564-07088.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/63792-15948.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/64678-09746.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/73538-09746.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/11518-14176.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/06202-07088.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/63792-07974.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/67336-15062.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/63792-12404.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/64678-13290.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/71766-10632.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/73538-13290.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/18606-10632.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/67336-07088.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/70880-18606.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/08860-07974.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/71766-08860.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/73538-11518.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/64678-11518.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/70880-16834.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/08860-09746.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/72652-10632.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/69108-08860.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/63792-11518.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/63792-13290.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/74424-14176.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/69108-10632.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/72652-08860.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/12404-08860.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/15062-07088.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/63792-09746.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/64678-07974.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/64678-12404.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/73538-12404.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/69994-15062.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/12404-10632.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/15948-05316.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/09746-09746.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/06202-04430.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/10632-07974.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/68222-15062.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/66450-07088.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/07974-07974.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/14176-12404.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/68222-07088.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/66450-15062.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/70880-07974.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/70880-12404.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/05316-04430.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/07974-02658.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/68222-08860.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/68222-10632.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/70880-15948.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/07088-03544.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/05316-05316.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/66450-08860.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/09746-14176.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/64678-16834.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/73538-16834.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/10632-02658.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/66450-10632.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/74424-13290.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/72652-15062.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/63792-14176.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/15062-10632.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/10632-03544.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/11518-07974.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/12404-07088.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/69108-15062.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/74424-11518.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/69994-08860.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/08860-14176.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/17720-08860.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/74424-09746.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/17720-10632.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/07974-03544.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/69994-10632.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/69108-07088.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/08860-02658.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/67336-08860.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/74424-12404.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/05316-07088.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/73538-17720.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/74424-15948.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/67336-10632.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/14176-06202.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/71766-15062.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/13290-10632.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/64678-14176.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/73538-14176.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/11518-09746.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/09746-03544.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/16834-05316.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/65564-08860.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/62020-10632.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/09746-02658.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/62906-15062.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/15948-08860.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/70880-13290.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/10632-14176.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/70880-11518.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/15948-10632.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/62020-08860.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/65564-10632.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/75310-15062.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/70880-09746.jpg
#   inflating: Fold1/Validation/Epithelioid/TCGA-3H-AB3L-01A-01-TS1.D473695C-02B1-4663-9E73-FF25EE57796F.svs/08860-03544.jpg
# Collecting git+https://github.com/qubvel/classification_models.git
#   Cloning https://github.com/qubvel/classification_models.git to /tmp/pip-req-build-b2kkfznz
#   Running command git clone -q https://github.com/qubvel/classification_models.git /tmp/pip-req-build-b2kkfznz
#   Running command git submodule update --init --recursive -q
# Requirement already satisfied (use --upgrade to upgrade): image-classifiers==1.0.0 from git+https://github.com/qubvel/classification_models.git in /usr/local/lib/python3.6/dist-packages
# Requirement already satisfied: keras_applications<=1.0.8,>=1.0.7 in /usr/local/lib/python3.6/dist-packages (from image-classifiers==1.0.0) (1.0.8)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras_applications<=1.0.8,>=1.0.7->image-classifiers==1.0.0) (1.18.5)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras_applications<=1.0.8,>=1.0.7->image-classifiers==1.0.0) (2.10.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from h5py->keras_applications<=1.0.8,>=1.0.7->image-classifiers==1.0.0) (1.15.0)
# Building wheels for collected packages: image-classifiers
#   Building wheel for image-classifiers (setup.py) ... done
#   Created wheel for image-classifiers: filename=image_classifiers-1.0.0-cp36-none-any.whl size=20032 sha256=bb470ee7dced9e1daa8aa761d2ccbeab9ead684e21504a5f296d97c9b4d33998
#   Stored in directory: /tmp/pip-ephem-wheel-cache-wxedoj9d/wheels/de/2b/fd/29a6d33edb8c28bc7d94e95ea1d39c9a218ac500a3cfb1b197
# Successfully built image-classifiers

# %%
#related modules 
import keras
import numpy as np
from keras.models import Sequential
from keras.layers.convolutional import Convolution2D
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D,AveragePooling2D
from keras.layers.advanced_activations import LeakyReLU
from keras.callbacks import EarlyStopping,ModelCheckpoint
from keras.models import load_model
from keras.layers.normalization import BatchNormalization
from classification_models.keras import Classifiers
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import KFold, StratifiedKFold
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve,roc_auc_score,precision_recall_curve,auc
from sklearn.metrics import average_precision_score
import tensorflow as tf
from sklearn.utils import class_weight
from keras.callbacks import EarlyStopping
from keras.preprocessing import image
import os
import glob
import pandas as pd
from fnmatch import fnmatch

# %%
train_path = "Fold1/Train"
val_path = "Fold1/Validation"
test_path ="Fold1/Test"

batch_size = 64

loss_function ='categorical_crossentropy'
patience = 10
epoch = 50
final_activation ='softmax'
file_pattern = "*.jpg"
folder_pattern = "*TCGA-*"


Resnet18_model,preprocess_input = Classifiers.get('resnet18')
base_resnet18model = Resnet18_model(input_shape=(224,224,3), weights='imagenet', include_top=False)
base_resnet18model.summary()

#reading train and validation data
data_generator = ImageDataGenerator(rescale = 1./255,preprocessing_function=  preprocess_input)
#loop and iterating through train images
train_data_generator = data_generator.flow_from_directory(train_path,class_mode ='categorical',batch_size = batch_size,target_size = (224,224),shuffle =True)
#iterating through images of validation set
val_data_generator = data_generator.flow_from_directory(val_path,class_mode ='categorical',batch_size = batch_size,target_size = (224,224),shuffle = True)
#class wight balance

#class wight balance
# classes = train_data_generator.classes
class_weights_list = class_weight.compute_class_weight('balanced',np.unique(train_data_generator.classes),train_data_generator.classes)
weights = dict(zip(np.unique(train_data_generator.classes),class_weights_list))
print("weights ratio to make the dataset balanced: ",weights)

print("class Indices of train generator :",train_data_generator.class_indices)
print("class Indices of validation generator :",val_data_generator.class_indices)
# Out:
# Model: "functional_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# data (InputLayer)               [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# bn_data (BatchNormalization)    (None, 224, 224, 3)  9           data[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_18 (ZeroPadding2 (None, 230, 230, 3)  0           bn_data[0][0]
# __________________________________________________________________________________________________
# conv0 (Conv2D)                  (None, 112, 112, 64) 9408        zero_padding2d_18[0][0]
# __________________________________________________________________________________________________
# bn0 (BatchNormalization)        (None, 112, 112, 64) 256         conv0[0][0]
# __________________________________________________________________________________________________
# relu0 (Activation)              (None, 112, 112, 64) 0           bn0[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_19 (ZeroPadding2 (None, 114, 114, 64) 0           relu0[0][0]
# __________________________________________________________________________________________________
# pooling0 (MaxPooling2D)         (None, 56, 56, 64)   0           zero_padding2d_19[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_bn1 (BatchNormaliz (None, 56, 56, 64)   256         pooling0[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_relu1 (Activation) (None, 56, 56, 64)   0           stage1_unit1_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_20 (ZeroPadding2 (None, 58, 58, 64)   0           stage1_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_conv1 (Conv2D)     (None, 56, 56, 64)   36864       zero_padding2d_20[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_bn2 (BatchNormaliz (None, 56, 56, 64)   256         stage1_unit1_conv1[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_relu2 (Activation) (None, 56, 56, 64)   0           stage1_unit1_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_21 (ZeroPadding2 (None, 58, 58, 64)   0           stage1_unit1_relu2[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_conv2 (Conv2D)     (None, 56, 56, 64)   36864       zero_padding2d_21[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_sc (Conv2D)        (None, 56, 56, 64)   4096        stage1_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 56, 56, 64)   0           stage1_unit1_conv2[0][0]
#                                                                  stage1_unit1_sc[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_bn1 (BatchNormaliz (None, 56, 56, 64)   256         add_8[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_relu1 (Activation) (None, 56, 56, 64)   0           stage1_unit2_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_22 (ZeroPadding2 (None, 58, 58, 64)   0           stage1_unit2_relu1[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_conv1 (Conv2D)     (None, 56, 56, 64)   36864       zero_padding2d_22[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_bn2 (BatchNormaliz (None, 56, 56, 64)   256         stage1_unit2_conv1[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_relu2 (Activation) (None, 56, 56, 64)   0           stage1_unit2_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_23 (ZeroPadding2 (None, 58, 58, 64)   0           stage1_unit2_relu2[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_conv2 (Conv2D)     (None, 56, 56, 64)   36864       zero_padding2d_23[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 56, 56, 64)   0           stage1_unit2_conv2[0][0]
#                                                                  add_8[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_bn1 (BatchNormaliz (None, 56, 56, 64)   256         add_9[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_relu1 (Activation) (None, 56, 56, 64)   0           stage2_unit1_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_24 (ZeroPadding2 (None, 58, 58, 64)   0           stage2_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_conv1 (Conv2D)     (None, 28, 28, 128)  73728       zero_padding2d_24[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_bn2 (BatchNormaliz (None, 28, 28, 128)  512         stage2_unit1_conv1[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_relu2 (Activation) (None, 28, 28, 128)  0           stage2_unit1_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_25 (ZeroPadding2 (None, 30, 30, 128)  0           stage2_unit1_relu2[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_conv2 (Conv2D)     (None, 28, 28, 128)  147456      zero_padding2d_25[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_sc (Conv2D)        (None, 28, 28, 128)  8192        stage2_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 28, 28, 128)  0           stage2_unit1_conv2[0][0]
#                                                                  stage2_unit1_sc[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_bn1 (BatchNormaliz (None, 28, 28, 128)  512         add_10[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_relu1 (Activation) (None, 28, 28, 128)  0           stage2_unit2_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_26 (ZeroPadding2 (None, 30, 30, 128)  0           stage2_unit2_relu1[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_conv1 (Conv2D)     (None, 28, 28, 128)  147456      zero_padding2d_26[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_bn2 (BatchNormaliz (None, 28, 28, 128)  512         stage2_unit2_conv1[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_relu2 (Activation) (None, 28, 28, 128)  0           stage2_unit2_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_27 (ZeroPadding2 (None, 30, 30, 128)  0           stage2_unit2_relu2[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_conv2 (Conv2D)     (None, 28, 28, 128)  147456      zero_padding2d_27[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 28, 28, 128)  0           stage2_unit2_conv2[0][0]
#                                                                  add_10[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_bn1 (BatchNormaliz (None, 28, 28, 128)  512         add_11[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_relu1 (Activation) (None, 28, 28, 128)  0           stage3_unit1_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_28 (ZeroPadding2 (None, 30, 30, 128)  0           stage3_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_conv1 (Conv2D)     (None, 14, 14, 256)  294912      zero_padding2d_28[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_bn2 (BatchNormaliz (None, 14, 14, 256)  1024        stage3_unit1_conv1[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_relu2 (Activation) (None, 14, 14, 256)  0           stage3_unit1_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_29 (ZeroPadding2 (None, 16, 16, 256)  0           stage3_unit1_relu2[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_conv2 (Conv2D)     (None, 14, 14, 256)  589824      zero_padding2d_29[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_sc (Conv2D)        (None, 14, 14, 256)  32768       stage3_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 14, 14, 256)  0           stage3_unit1_conv2[0][0]
#                                                                  stage3_unit1_sc[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_bn1 (BatchNormaliz (None, 14, 14, 256)  1024        add_12[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_relu1 (Activation) (None, 14, 14, 256)  0           stage3_unit2_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_30 (ZeroPadding2 (None, 16, 16, 256)  0           stage3_unit2_relu1[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_conv1 (Conv2D)     (None, 14, 14, 256)  589824      zero_padding2d_30[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_bn2 (BatchNormaliz (None, 14, 14, 256)  1024        stage3_unit2_conv1[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_relu2 (Activation) (None, 14, 14, 256)  0           stage3_unit2_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_31 (ZeroPadding2 (None, 16, 16, 256)  0           stage3_unit2_relu2[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_conv2 (Conv2D)     (None, 14, 14, 256)  589824      zero_padding2d_31[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 14, 14, 256)  0           stage3_unit2_conv2[0][0]
#                                                                  add_12[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_bn1 (BatchNormaliz (None, 14, 14, 256)  1024        add_13[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_relu1 (Activation) (None, 14, 14, 256)  0           stage4_unit1_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_32 (ZeroPadding2 (None, 16, 16, 256)  0           stage4_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_conv1 (Conv2D)     (None, 7, 7, 512)    1179648     zero_padding2d_32[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_bn2 (BatchNormaliz (None, 7, 7, 512)    2048        stage4_unit1_conv1[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_relu2 (Activation) (None, 7, 7, 512)    0           stage4_unit1_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_33 (ZeroPadding2 (None, 9, 9, 512)    0           stage4_unit1_relu2[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_conv2 (Conv2D)     (None, 7, 7, 512)    2359296     zero_padding2d_33[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_sc (Conv2D)        (None, 7, 7, 512)    131072      stage4_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 7, 7, 512)    0           stage4_unit1_conv2[0][0]
#                                                                  stage4_unit1_sc[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_bn1 (BatchNormaliz (None, 7, 7, 512)    2048        add_14[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_relu1 (Activation) (None, 7, 7, 512)    0           stage4_unit2_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_34 (ZeroPadding2 (None, 9, 9, 512)    0           stage4_unit2_relu1[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_conv1 (Conv2D)     (None, 7, 7, 512)    2359296     zero_padding2d_34[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_bn2 (BatchNormaliz (None, 7, 7, 512)    2048        stage4_unit2_conv1[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_relu2 (Activation) (None, 7, 7, 512)    0           stage4_unit2_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_35 (ZeroPadding2 (None, 9, 9, 512)    0           stage4_unit2_relu2[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_conv2 (Conv2D)     (None, 7, 7, 512)    2359296     zero_padding2d_35[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 7, 7, 512)    0           stage4_unit2_conv2[0][0]
#                                                                  add_14[0][0]
# __________________________________________________________________________________________________
# bn1 (BatchNormalization)        (None, 7, 7, 512)    2048        add_15[0][0]
# __________________________________________________________________________________________________
# relu1 (Activation)              (None, 7, 7, 512)    0           bn1[0][0]
# ==================================================================================================
# Total params: 11,186,889
# Trainable params: 11,178,947
# Non-trainable params: 7,942
# __________________________________________________________________________________________________
# Found 41730 images belonging to 2 classes.
# Found 20545 images belonging to 2 classes.
# weights ratio to make the dataset balanced:  {0: 0.6805061804898731, 1: 1.8849941277441504}
# class Indices of train generator : {'Epithelioid': 0, 'Nonepithelioid': 1}
# class Indices of validation generator : {'Epithelioid': 0, 'Nonepithelioid': 1}

# %%
def training_model(pretrained_model,final_activation):
    model = Sequential()
    model.add(pretrained_model) #pretrained model
    model.add(Flatten()) #creating a single 1-d vector
    model.add(Dense(2,activation=final_activation))#output layer with softmax activation function.
    return model

#this function takes the each patch in WSI then predicts the probability score
def pred_each_patch(path,name):
    y = image.load_img(os.path.join(path, name))
    img = image.img_to_array(y)
    y = np.expand_dims(img, axis = 0)
    y = preprocess_input(y)
    y /= 255
    y_pred = model.predict(y)
    return y_pred
        
def avg(predlist):
    average = sum(predlist)/len(predlist)
    return average

def extract_index_one_frmpred(prediction_list):               
    ypred = np.stack(prediction_list)#we are vertically stacking the predictions
    ypred = np.reshape(ypred, [len(prediction_list),2])#reshaping to 100,2 - np array
    for each in ypred:
    #after reshaping the predictions as we wanted, we are taking the index '1' to compute whole slide level AUC-ROC
        val = each[1]
        pred_prob_list.append(val)#appending all the values into a list - to compute average values of single WSI and maximum of single WSI.
        
    return pred_prob_list
    
def plt_history(history): 
    
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epochs')
    plt.legend(['train', 'validation'], loc='upper right')
    plt.tight_layout() 
    plt.show()
    return

def y_labels(path):
  if "Epithelioid" in path:
    y_test_labels.append(0.0)
  elif "Nonepithelioid" in path:
    y_test_labels.append(1.0) 
  return

def prediction_scores(y_test_labels,AVG_LIST_PREDICTIONS,MAX_LIST_PREDICTIONS):
  #AUC - ROC score
  false_pr_avg,true_pr_avg,threshold = roc_curve(y_test_labels,AVG_LIST_PREDICTIONS)
  roc_auc_avg = auc(false_pr_avg,true_pr_avg)
  print("AUC - ROC on Test data average prediction scores:",roc_auc_avg)
  print("-----------------------------------------------------")
  plt.plot(false_pr_avg,true_pr_avg,color='green',label='ROC curve on test data(area = %0.2f)' %(auc(false_pr_avg,true_pr_avg)))
  plt.plot([0, 1], [0, 1], color='navy', linestyle='--',label = 'Random')
  plt.xlabel("False positive rate")
  plt.ylabel("True positive rate")
  plt.title('ROC curve on Test data (area = %0.2f)' %(auc(false_pr_avg,true_pr_avg)))
  plt.legend(loc = "lower right")
  plt.tight_layout()
  plt.show()
  
  false_pr_max,true_pr_max,threshold = roc_curve(y_test_labels,MAX_LIST_PREDICTIONS)
  roc_auc_max = auc(false_pr_max,true_pr_max)
  print("AUC - ROC on Test data maximum prediction scores:",roc_auc_max)
  print("-----------------------------------------------------")
  plt.plot(false_pr_max,true_pr_max,color='magenta',label='ROC curve on test data(area = %0.2f)' %(auc(false_pr_max,true_pr_max)))
  plt.plot([0, 1], [0, 1], color='navy', linestyle='--',label = 'Random')
  plt.xlabel("False positive rate")
  plt.ylabel("True positive rate")
  plt.title('ROC curve on Test data (area = %0.2f)' %(auc(false_pr_max,true_pr_max)))
  plt.legend(loc = "lower right")
  plt.tight_layout()
  plt.show()
 

def pre_recall(y_test_labels,AVG_LIST_PREDICTIONS,MAX_LIST_PREDICTIONS):
  #presicion - recall curve
  precision, recall, threshold = precision_recall_curve(y_test_labels,AVG_LIST_PREDICTIONS)
  print("Presicion - Recall auc on test data average score predictions:",auc(recall,precision))
 
  print("-----------------------------------------------------")
  plt.plot(precision, recall,color='orange',label='PR curve (area = %0.2f)' %(auc(recall,precision)))
  plt.xlabel("Recall")
  plt.ylabel("Precision")
  plt.title('Presicion Recall curve on Test data (area = %0.2f)' %(auc(recall,precision)))
  plt.legend(loc = "lower right")
  plt.tight_layout()
  plt.show()

  precision_max, recall_max, threshold = precision_recall_curve(y_test_labels,MAX_LIST_PREDICTIONS)
  print("Presicion - Recall auc on test data maximum score predictions:",auc(recall_max,precision_max))
 
  print("-----------------------------------------------------")
  plt.plot(precision_max, recall_max,color='cyan',label='PR curve (area = %0.2f)' %(auc(recall_max,precision_max)))
  plt.xlabel("Recall")
  plt.ylabel("Precision")
  plt.title('Presicion Recall curve on Test data (area = %0.2f)' %(auc(recall_max,precision_max)))
  plt.legend(loc = "lower right")
  plt.tight_layout()
  plt.show()

# %%
from keras.models import load_model

model = training_model(base_resnet18model,final_activation)  

reduce_lr = keras.callbacks.ReduceLROnPlateau(monitor = 'val_loss',factor = 0.1,patience=3,verbose = 1)
# early stopping to prevent overfitting
es = EarlyStopping(monitor='val_loss',verbose=1, patience=patience)

opt_nadam = tf.keras.optimizers.Nadam(1e-4)#Adam with Nestrov momentum

model.compile(optimizer= opt_nadam, loss=loss_function,metrics = [tf.keras.metrics.AUC(),tf.keras.metrics.Precision(),tf.keras.metrics.Recall()])

#Initilaising the model
history = model.fit(train_data_generator, steps_per_epoch=len(train_data_generator.classes)//batch_size, validation_data=val_data_generator,epochs = epoch,class_weight = weights,callbacks =[es,reduce_lr],workers = 4)
    
plt_history(history)#model_loss_plot
# Out:
# Epoch 1/50
# 652/652 [==============================] - 378s 580ms/step - loss: 0.6363 - auc_1: 0.8284 - precision_1: 0.7438 - recall_1: 0.7438 - val_loss: 0.6461 - val_auc_1: 0.6736 - val_precision_1: 0.6565 - val_recall_1: 0.6565
# Epoch 2/50
# 652/652 [==============================] - 376s 577ms/step - loss: 0.2588 - auc_1: 0.9624 - precision_1: 0.9006 - recall_1: 0.9006 - val_loss: 1.4965 - val_auc_1: 0.6908 - val_precision_1: 0.6397 - val_recall_1: 0.6397
# Epoch 3/50
# 652/652 [==============================] - 377s 578ms/step - loss: 0.0974 - auc_1: 0.9937 - precision_1: 0.9613 - recall_1: 0.9613 - val_loss: 1.7522 - val_auc_1: 0.6493 - val_precision_1: 0.6073 - val_recall_1: 0.6073
# Epoch 4/50
# 652/652 [==============================] - ETA: 0s - loss: 0.0486 - auc_1: 0.9984 - precision_1: 0.9817 - recall_1: 0.9817
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 652/652 [==============================] - 377s 578ms/step - loss: 0.0486 - auc_1: 0.9984 - precision_1: 0.9817 - recall_1: 0.9817 - val_loss: 2.1379 - val_auc_1: 0.7706 - val_precision_1: 0.7228 - val_recall_1: 0.7228
# Epoch 5/50
# 652/652 [==============================] - 377s 578ms/step - loss: 0.0226 - auc_1: 0.9997 - precision_1: 0.9928 - recall_1: 0.9928 - val_loss: 1.8755 - val_auc_1: 0.7152 - val_precision_1: 0.6662 - val_recall_1: 0.6662
# Epoch 6/50
# 652/652 [==============================] - 377s 578ms/step - loss: 0.0121 - auc_1: 0.9999 - precision_1: 0.9973 - recall_1: 0.9973 - val_loss: 1.8564 - val_auc_1: 0.6806 - val_precision_1: 0.6359 - val_recall_1: 0.6359
# Epoch 7/50
# 652/652 [==============================] - ETA: 0s - loss: 0.0082 - auc_1: 1.0000 - precision_1: 0.9984 - recall_1: 0.9984
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 652/652 [==============================] - 377s 579ms/step - loss: 0.0082 - auc_1: 1.0000 - precision_1: 0.9984 - recall_1: 0.9984 - val_loss: 1.9163 - val_auc_1: 0.7353 - val_precision_1: 0.6838 - val_recall_1: 0.6838
# Epoch 8/50
# 652/652 [==============================] - 379s 581ms/step - loss: 0.0056 - auc_1: 1.0000 - precision_1: 0.9993 - recall_1: 0.9993 - val_loss: 1.9057 - val_auc_1: 0.7266 - val_precision_1: 0.6751 - val_recall_1: 0.6751
# Epoch 9/50
# 652/652 [==============================] - 378s 580ms/step - loss: 0.0061 - auc_1: 1.0000 - precision_1: 0.9991 - recall_1: 0.9991 - val_loss: 1.9115 - val_auc_1: 0.7269 - val_precision_1: 0.6758 - val_recall_1: 0.6758
# Epoch 10/50
# 652/652 [==============================] - ETA: 0s - loss: 0.0054 - auc_1: 1.0000 - precision_1: 0.9992 - recall_1: 0.9992
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
# 652/652 [==============================] - 378s 579ms/step - loss: 0.0054 - auc_1: 1.0000 - precision_1: 0.9992 - recall_1: 0.9992 - val_loss: 1.9263 - val_auc_1: 0.7288 - val_precision_1: 0.6774 - val_recall_1: 0.6774
# Epoch 11/50
# 652/652 [==============================] - 378s 580ms/step - loss: 0.0054 - auc_1: 1.0000 - precision_1: 0.9992 - recall_1: 0.9992 - val_loss: 1.9345 - val_auc_1: 0.7280 - val_precision_1: 0.6768 - val_recall_1: 0.6768
# Epoch 00011: early stopping

# %% [markdown]
# **Evaluation on Validation set**

# %%
AVG_LIST_PREDICTIONS_VAL = []
MAX_LIST_PREDICTIONS_VAL = []
y_val_labels= []
print("Prediction on validation data using aggregation method")
for path, subdirs, files in os.walk(val_path): #iterating through folders of each WSI
    if(fnmatch(path,folder_pattern)):
        WSI_pred = list()
        pred_prob_list = list()
        # print("Iterating through all the patches in: ",os.path.basename(os.path.normpath(path)))
        if "Epithelioid" in path:
          y_val_labels.append(0.0)
        elif "Nonepithelioid" in path:
          y_val_labels.append(1.0) 

        for name in files:
          if fnmatch(name, file_pattern):#iterating through each patch in all WSI image and computing probabilities
              prediction = pred_each_patch(path,name)
              WSI_pred.append(prediction)#this list contains probabilities of all patches in testset images

        #computing average and maximum prediction of each image - so that we can compute Whole slide level AUC - ROC than patch level
        predictions = extract_index_one_frmpred(WSI_pred)
        #This list contains average score of all 36 test set images
        AVG_LIST_PREDICTIONS_VAL.append(avg(predictions))
        MAX_LIST_PREDICTIONS_VAL.append(max(predictions))
# Out:
# Prediction on validation data using aggregation method

# %%
#creating a datframe to save predictions with actuals
df_val = pd.DataFrame()
df_val['Average'] = AVG_LIST_PREDICTIONS_VAL
df_val['Maximum'] = MAX_LIST_PREDICTIONS_VAL
df_val['Actual labels'] = y_val_labels
#saving into csv file for futher use
df_val.to_csv('FOLD1_500_res18_val.csv',index = False,header = True)
# !cp FOLD1_500_res18_val.csv "drive/My Drive/"

# %% [markdown]
# **AUC-ROC curves**

# %%
false_pr_avg,true_pr_avg,threshold = roc_curve(y_val_labels,AVG_LIST_PREDICTIONS_VAL)
roc_auc_avg = auc(false_pr_avg,true_pr_avg)
print("AUC - ROC on validation data average prediction scores:",roc_auc_avg)
print("-----------------------------------------------------")
plt.plot(false_pr_avg,true_pr_avg,color='green',label='ROC curve on validation data(area = %0.2f)' %(auc(false_pr_avg,true_pr_avg)))
plt.plot([0, 1], [0, 1], color='navy', linestyle='--',label = 'Random')
plt.xlabel("False positive rate")
plt.ylabel("True positive rate")
plt.title('ROC curve on validation data (area = %0.2f)' %(auc(false_pr_avg,true_pr_avg)))
plt.legend(loc = "lower right")
plt.tight_layout()
plt.show()
# Out:
# AUC - ROC on validation data average prediction scores: 0.7081447963800905
# -----------------------------------------------------

# %%
false_pr_max,true_pr_max,threshold = roc_curve(y_val_labels,MAX_LIST_PREDICTIONS_VAL)
roc_auc_max = auc(false_pr_max,true_pr_max)
print("AUC - ROC on validation data maximum prediction scores:",roc_auc_max)
print("-----------------------------------------------------")
plt.plot(false_pr_max,true_pr_max,color='magenta',label='ROC curve on validation data(area = %0.2f)' %(auc(false_pr_max,true_pr_max)))
plt.plot([0, 1], [0, 1], color='navy', linestyle='--',label = 'Random')
plt.xlabel("False positive rate")
plt.ylabel("True positive rate")
plt.title('ROC curve on validation data (area = %0.2f)' %(auc(false_pr_max,true_pr_max)))
plt.legend(loc = "lower right")
plt.tight_layout()
plt.show()
# Out:
# AUC - ROC on validation data maximum prediction scores: 0.6527149321266968
# -----------------------------------------------------

# %% [markdown]
# **PR Curves**

# %%
#presicion - recall curve
precision, recall, threshold = precision_recall_curve(y_val_labels,AVG_LIST_PREDICTIONS_VAL)
print("Presicion - Recall auc on validation data average score predictions:",auc(recall,precision))
 
print("-----------------------------------------------------")
plt.plot(precision, recall,color='red',label='PR curve (area = %0.2f)' %(auc(recall,precision)))
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title('Presicion Recall curve on validation data (area = %0.2f)' %(auc(recall,precision)))
plt.legend(loc = "lower right")
plt.tight_layout()
plt.show()

precision_max, recall_max, threshold = precision_recall_curve(y_val_labels,MAX_LIST_PREDICTIONS_VAL)
print("Presicion - Recall auc on validation data maximum score predictions:",auc(recall_max,precision_max))
print("-----------------------------------------------------")
plt.plot(precision_max, recall_max,color='blue',label='PR curve (area = %0.2f)' %(auc(recall_max,precision_max)))
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title('Presicion Recall curve on validation data (area = %0.2f)' %(auc(recall_max,precision_max)))
plt.legend(loc = "lower right")
plt.tight_layout()
plt.show()
# Out:
# Presicion - Recall auc on validation data average score predictions: 0.4568769603964966
# -----------------------------------------------------
# Presicion - Recall auc on validation data maximum score predictions: 0.45784771331441126
# -----------------------------------------------------

# %% [markdown]
# **CLASSIFICATION REPORT**

# %%
import sklearn
#classification report on average prediction values
AVG_LIST_PREDICTIONS_VAL = [round(x) for x in AVG_LIST_PREDICTIONS_VAL]
print("CLASSIFICATION REPORT for AVERAGE SCORE PREDICTIONS")
print(sklearn.metrics.classification_report(y_val_labels,AVG_LIST_PREDICTIONS_VAL))
# Out:
# CLASSIFICATION REPORT for AVERAGE SCORE PREDICTIONS
#               precision    recall  f1-score   support
#
#          0.0       0.76      0.91      0.83        34
#          1.0       0.50      0.23      0.32        13
#
#     accuracy                           0.72        47
#    macro avg       0.63      0.57      0.57        47
# weighted avg       0.69      0.72      0.69        47

# %%
#classification report on maximum prediction values
MAX_LIST_PREDICTIONS_VAL = [round(x) for x in MAX_LIST_PREDICTIONS_VAL]
print("CLASSIFICATION REPORT for MAXIMUM SCORE PREDICTIONS")
print(sklearn.metrics.classification_report(y_val_labels,MAX_LIST_PREDICTIONS_VAL))
# Out:
# CLASSIFICATION REPORT for MAXIMUM SCORE PREDICTIONS
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00        34
#          1.0       0.28      1.00      0.43        13
#
#     accuracy                           0.28        47
#    macro avg       0.14      0.50      0.22        47
# weighted avg       0.08      0.28      0.12        47
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# **Evaluation on Test Data**

# %%
AVG_LIST_PREDICTIONS = []
MAX_LIST_PREDICTIONS = []
y_test_labels= []

for path, subdirs, files in os.walk(test_path): #iterating through folders of each WSI
    if(fnmatch(path,folder_pattern)):
        WSI_pred = list()
        pred_prob_list = list()
        # print("Iterating through all the patches in: ",os.path.normpath(path))
        y_labels(path)

        for name in files:
          if fnmatch(name, file_pattern):#iterating through each patch in all WSI image and computing probabilities
              prediction = pred_each_patch(path,name)
              WSI_pred.append(prediction)#this list contains probabilities of all patches in testset images

        #computing average and maximum prediction of each image - so that we can compute Whole slide level AUC - ROC than patch level
        predictions = extract_index_one_frmpred(WSI_pred)
        #This list contains average score of all 36 test set images
        AVG_LIST_PREDICTIONS.append(avg(predictions))
        MAX_LIST_PREDICTIONS.append(max(predictions))

# %%
#creating a datframe to save predictions with actuals
df = pd.DataFrame()
df['Average'] = AVG_LIST_PREDICTIONS
df['Maximum'] = MAX_LIST_PREDICTIONS
df['Actual labels'] = y_test_labels
#saving into csv file for futher use
df.to_csv('FOLD1_500_resnet18_test.csv',index = False,header = True)
# !cp FOLD1_500_resnet18_test.csv "drive/My Drive/"

# %%
#AUC-ROC SCORES
prediction_scores(y_test_labels,AVG_LIST_PREDICTIONS,MAX_LIST_PREDICTIONS)
# Out:
# AUC - ROC on Test data average prediction scores: 0.654320987654321
# -----------------------------------------------------
# AUC - ROC on Test data maximum prediction scores: 0.5781893004115226
# -----------------------------------------------------

# %%
#Prescion - Recall Curves
pre_recall(y_test_labels,AVG_LIST_PREDICTIONS,MAX_LIST_PREDICTIONS)
# Out:
# Presicion - Recall auc on test data average score predictions: 0.39199587177528356
# -----------------------------------------------------
# Presicion - Recall auc on test data maximum score predictions: 0.3575797695933596
# -----------------------------------------------------

# %%
#Classification report
AVG_LIST_PREDICTIONS = [round(x) for x in AVG_LIST_PREDICTIONS]
print("CLASSIFICATION REPORT")
print(sklearn.metrics.classification_report(y_test_labels,AVG_LIST_PREDICTIONS))
# Out:
# CLASSIFICATION REPORT
#               precision    recall  f1-score   support
#
#          0.0       0.75      1.00      0.86        27
#          1.0       0.00      0.00      0.00         9
#
#     accuracy                           0.75        36
#    macro avg       0.38      0.50      0.43        36
# weighted avg       0.56      0.75      0.64        36
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
MAX_LIST_PREDICTIONS = [round(x) for x in MAX_LIST_PREDICTIONS]
print("CLASSIFICATION REPORT for MAX VALUE PREDICTIONS")
print(sklearn.metrics.classification_report(y_test_labels,MAX_LIST_PREDICTIONS))
# Out:
# CLASSIFICATION REPORT for MAX VALUE PREDICTIONS
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00        27
#          1.0       0.25      1.00      0.40         9
#
#     accuracy                           0.25        36
#    macro avg       0.12      0.50      0.20        36
# weighted avg       0.06      0.25      0.10        36
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# **Saving the best model**

# %%
model.save("fold1_resnet18_500.h5")
# !cp fold1_resnet18_500.h5 "drive/My Drive"
