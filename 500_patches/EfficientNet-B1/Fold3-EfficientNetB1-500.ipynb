# %%
from google.colab import drive
drive.mount('/content/drive')
#loading the dataset and extracting from the zip file
# !unzip drive/My\ Drive/Fold3.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/55818-10632.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/62020-02658.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/21264-17720.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/75310-12404.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/54932-06202.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/58476-04430.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/17720-18606.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/18606-23036.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/68222-14176.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/62906-12404.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/60248-02658.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/61134-07974.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/62906-07974.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/25694-18606.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/61134-12404.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/57590-06202.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/67336-16834.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/21264-14176.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/10632-13290.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/22150-14176.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/61134-10632.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/62906-10632.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/14176-09746.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/15948-21264.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/17720-22150.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/15948-20378.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/57590-04430.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/60248-07088.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/62906-08860.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/15948-15062.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/70880-14176.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/57590-05316.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/61134-08860.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/10632-11518.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/07974-11518.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/55818-07974.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/58476-06202.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/62020-07088.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/14176-11518.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/09746-15948.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/11518-06202.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/15062-05316.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/22150-17720.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/70880-17720.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/10632-09746.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/15948-07088.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/59362-07088.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/14176-13290.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/65564-07088.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/54932-05316.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/09746-07974.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/09746-12404.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/13290-07088.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/07088-11518.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/22150-19492.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/66450-04430.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/52274-10632.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/73538-09746.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/11518-14176.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/58476-14176.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/66450-05316.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/19492-09746.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/67336-15062.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/63792-12404.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/64678-13290.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/71766-10632.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/73538-13290.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/22150-18606.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/19492-13290.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/08860-15948.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/13290-15062.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/18606-10632.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/18606-08860.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/67336-07088.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/19492-11518.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/21264-22150.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/08860-07974.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/71766-08860.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/08860-12404.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/73538-11518.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/05316-10632.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/64678-11518.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/23036-15948.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/70880-16834.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/08860-09746.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/72652-10632.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/69108-08860.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/20378-10632.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/63792-11518.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/60248-04430.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/57590-07088.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/63792-13290.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/15062-21264.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/74424-14176.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/69108-10632.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/15062-20378.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/22150-16834.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/12404-08860.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/15062-07088.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/63792-09746.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/16834-10632.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/62020-05316.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/19492-12404.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/17720-20378.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/65564-04430.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/64678-07974.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/25694-20378.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/64678-12404.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/59362-04430.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/08860-11518.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/73538-12404.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/17720-21264.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/19492-15948.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/08860-13290.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/17720-15062.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/62020-04430.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/16834-08860.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/65564-05316.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/12404-10632.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/15948-05316.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/09746-09746.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/58476-03544.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/24808-20378.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/19492-23036.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/10632-07974.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/21264-15062.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/10632-12404.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/24808-21264.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/13290-05316.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/21264-21264.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/23922-15948.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/68222-15062.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/56704-06202.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/21264-20378.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/55818-09746.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/54046-06202.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/09746-11518.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/14176-15948.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/09746-13290.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/55818-11518.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/07974-12404.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/14176-12404.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/68222-07088.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/14176-07974.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/67336-05316.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/70880-07974.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/70880-12404.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/53160-10632.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/68222-08860.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/68222-10632.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/23036-16834.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/18606-22150.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/08860-06202.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/66450-08860.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/19492-16834.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/09746-14176.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/64678-03544.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/63792-06202.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/66450-10632.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/58476-12404.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/74424-13290.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/58476-07974.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/55818-06202.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/15062-10632.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/20378-15062.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/11518-12404.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/16834-07088.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/56704-09746.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/11518-07974.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/54932-10632.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/12404-07088.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/15062-08860.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/20378-21264.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/54046-11518.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/09746-06202.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/20378-20378.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/62906-05316.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/69994-08860.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/16834-15062.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/08860-14176.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/57590-08860.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/61134-05316.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/16834-20378.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/62906-04430.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/17720-10632.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/61134-04430.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/54046-09746.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/57590-10632.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/69994-10632.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/12404-15062.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/67336-08860.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/11518-13290.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/54046-12404.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/74424-12404.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/58476-13290.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/19492-17720.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/58476-11518.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/11518-11518.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/23922-19492.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/67336-10632.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/14176-06202.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/71766-15062.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/04430-11518.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/23036-17720.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/13290-10632.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/10632-06202.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/18606-15062.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/18606-21264.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/11518-09746.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/13290-08860.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/18606-20378.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/23922-18606.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/58476-09746.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/19492-14176.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/06202-10632.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/65564-08860.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/62020-10632.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/59362-08860.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/15948-08860.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/70880-13290.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/23036-19492.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/64678-06202.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/10632-14176.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/70880-11518.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/12404-05316.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/19492-18606.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/15948-10632.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/59362-10632.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/63792-03544.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/65564-10632.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/14176-14176.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/60248-08860.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/23036-18606.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/61134-07088.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/62906-07088.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/07974-14176.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/20378-22150.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/23922-17720.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/60248-10632.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-UD-AAC4-01A-01-TSA.56EBC99F-7844-41B4-AAAA-D4E87D2E772C.svs/19492-19492.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/74046-25284.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/73143-22575.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/07224-13545.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/20769-14448.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/63210-18060.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/77658-24381.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/12642-07224.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/21672-25284.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/18963-09030.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/77658-26187.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/61404-21672.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/12642-15351.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/09030-15351.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/78561-19866.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/06321-15351.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/63210-09030.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/74046-14448.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/16254-11739.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/09030-10836.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/69531-09933.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/66822-11739.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/16254-16254.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/22575-16254.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/18963-18060.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/08127-01806.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/66822-16254.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/18060-26187.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/64113-21672.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/14448-21672.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/68628-08127.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/13545-09030.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/11739-18060.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/21672-17157.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/65016-08127.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/76755-23478.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/72240-11739.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/75852-21672.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/67725-16254.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/73143-19866.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/12642-05418.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/15351-22575.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/05418-13545.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/09030-05418.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/20769-15351.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/71337-18963.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/65919-23478.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/13545-18060.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/10836-16254.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/14448-12642.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/18060-24381.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/74949-21672.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/09933-16254.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/78561-22575.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/12642-14448.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/06321-14448.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/09933-11739.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/17157-22575.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/12642-18060.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/09030-18060.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/20769-27090.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/63210-17157.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/61404-09933.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/70434-21672.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/76755-22575.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/19866-23478.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/06321-18060.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/17157-13545.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/61404-20769.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/13545-14448.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/62307-19866.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/11739-05418.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/09030-04515.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/15351-23478.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/66822-24381.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/65016-11739.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/12642-04515.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/68628-16254.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/18963-15351.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/09933-06321.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/63210-07224.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/05418-22575.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/61404-18963.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/12642-09030.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/06321-09030.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/18963-07224.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/09933-08127.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/74046-27090.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/70434-12642.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/13545-05418.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/11739-14448.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/08127-13545.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/69531-12642.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/63210-10836.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/10836-08127.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/78561-23478.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/74949-20769.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/14448-18963.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/62307-22575.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/65919-19866.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/73143-23478.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/18060-16254.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/21672-18060.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/11739-17157.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/18963-14448.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/75852-18963.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/72240-26187.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/76755-19866.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/63210-25284.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/71337-21672.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/74046-18060.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/14448-09933.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/72240-24381.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/18963-25284.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/11739-15351.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/64113-09933.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/13545-17157.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/67725-24381.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/14448-20769.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/73143-13545.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/74949-18963.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/13545-07224.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/07224-22575.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/71337-12642.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/20769-18060.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/60501-16254.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/64113-20769.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/04515-18963.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/05418-18060.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/73143-15351.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/17157-25284.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/73143-10836.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/19866-14448.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/68628-18963.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/65919-09030.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/66822-12642.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/15351-05418.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/61404-11739.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/77658-18963.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/65016-20769.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/15351-25284.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/73143-17157.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/61404-16254.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-LK-A4O4-01A-01-TSA.B4459B52-0435-4E2A-9546-3BC76FC41679.svs/06321-22575.jpg
# ...
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/48730-14176.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/24808-07088.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/25694-31896.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/33668-19492.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/28352-17720.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/45186-27466.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/38098-47844.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/47844-48730.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/38984-21264.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/21264-10632.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/46958-33668.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/37212-47844.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/43414-28352.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/50502-44300.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/26580-19492.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/46072-16834.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/31896-37212.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/40756-53160.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/28352-11518.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/32782-40756.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/46072-47844.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/43414-41642.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/44300-49616.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/37212-16834.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/11518-23036.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/44300-12404.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/21264-31010.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/48730-13290.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/26580-06202.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/45186-57590.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/24808-31010.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/46072-51388.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/30124-26580.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/48730-11518.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/31896-05316.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/43414-31010.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/52274-22150.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/46958-17720.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/39870-56704.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/24808-30124.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/34554-46072.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/43414-30124.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/20378-23922.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/35440-51388.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/24808-27466.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/39870-30124.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/08860-17720.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/15062-10632.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/46958-53160.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/11518-12404.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/33668-40756.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/27466-07974.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/45186-28352.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/34554-28352.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/43414-54932.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/20378-21264.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/44300-38984.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/21264-27466.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/11518-15948.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/27466-15948.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/09746-19492.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/25694-08860.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/39870-10632.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/08860-14176.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/47844-25694.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/33668-13290.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/16834-23922.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/16834-21264.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/25694-28352.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/14176-16834.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/42528-34554.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/46958-18606.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/30124-30124.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/14176-18606.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/52274-23922.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/51388-41642.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/42528-31010.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/49616-27466.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/31896-15062.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/29238-48730.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/38984-37212.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/32782-23036.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/51388-30124.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/21264-26580.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/35440-18606.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/11518-11518.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/38984-36326.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/42528-30124.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/36326-42528.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/46072-33668.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/33668-39870.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/30124-41642.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/33668-24808.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/46958-51388.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/18606-23922.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/46072-17720.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/28352-23036.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/38984-22150.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/18606-21264.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/26580-02658.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/37212-14176.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/09746-16834.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/23922-18606.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/51388-10632.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/33668-23036.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/49616-10632.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/12404-22150.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/37212-06202.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/15948-08860.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/26580-16834.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/46072-19492.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/31010-40756.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/22150-13290.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/15948-10632.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/28352-15948.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/49616-31010.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/42528-27466.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/36326-20378.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/31010-11518.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/29238-09746.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/49616-30124.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/20378-22150.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/49616-41642.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/31010-13290.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/10632-17720.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/36326-23922.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/20378-04430.jpg
#   inflating: Fold3/Validation/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/32782-49616.jpg

# %%
import keras
import numpy as np
from keras.models import Sequential
from keras.layers.convolutional import Convolution2D
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D,AveragePooling2D
from keras.layers.advanced_activations import LeakyReLU
from keras.callbacks import EarlyStopping,ModelCheckpoint
from keras.models import load_model
from keras.layers.normalization import BatchNormalization
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import KFold, StratifiedKFold
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve,roc_auc_score,precision_recall_curve,auc
from sklearn.metrics import average_precision_score
import tensorflow as tf
from sklearn.utils import class_weight
from keras.callbacks import EarlyStopping
from keras.preprocessing import image
import os
import glob
from fnmatch import fnmatch

# %%
train_path = "Fold3/Train"
val_path = "Fold3/Validation"
test_path ="Fold3/Test"

batch_size = 64

loss_function ='categorical_crossentropy'
patience = 10
epoch = 50
final_activation ='softmax'
file_pattern = "*.jpg"
folder_pattern = "*TCGA-*"

base_model = tf.keras.applications.EfficientNetB1(input_shape=(224,224,3), weights='imagenet', include_top=False)
base_model.summary()

#reading train and validation data
data_generator = ImageDataGenerator(rescale = 1./255)
#loop and iterating through train images
train_data_generator = data_generator.flow_from_directory(train_path,class_mode ='categorical',batch_size = batch_size,target_size = (224,224),shuffle =True)
#iterating through images of validation set
val_data_generator = data_generator.flow_from_directory(val_path,class_mode ='categorical',batch_size = batch_size,target_size = (224,224),shuffle = True)
#class wight balance

#class wight balance
# classes = train_data_generator.classes
class_weights_list = class_weight.compute_class_weight('balanced',np.unique(train_data_generator.classes),train_data_generator.classes)
weights = dict(zip(np.unique(train_data_generator.classes),class_weights_list))
print("weights ratio to make the dataset balanced: ",weights)

print("class Indices of train generator :",train_data_generator.class_indices)
print("class Indices of validation generator :",val_data_generator.class_indices)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb1_notop.h5
# 27025408/27018416 [==============================] - 1s 0us/step
# Model: "efficientnetb1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# rescaling (Rescaling)           (None, 224, 224, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# normalization (Normalization)   (None, 224, 224, 3)  7           rescaling[0][0]
# __________________________________________________________________________________________________
# stem_conv_pad (ZeroPadding2D)   (None, 225, 225, 3)  0           normalization[0][0]
# __________________________________________________________________________________________________
# stem_conv (Conv2D)              (None, 112, 112, 32) 864         stem_conv_pad[0][0]
# __________________________________________________________________________________________________
# stem_bn (BatchNormalization)    (None, 112, 112, 32) 128         stem_conv[0][0]
# __________________________________________________________________________________________________
# stem_activation (Activation)    (None, 112, 112, 32) 0           stem_bn[0][0]
# __________________________________________________________________________________________________
# block1a_dwconv (DepthwiseConv2D (None, 112, 112, 32) 288         stem_activation[0][0]
# __________________________________________________________________________________________________
# block1a_bn (BatchNormalization) (None, 112, 112, 32) 128         block1a_dwconv[0][0]
# __________________________________________________________________________________________________
# block1a_activation (Activation) (None, 112, 112, 32) 0           block1a_bn[0][0]
# __________________________________________________________________________________________________
# block1a_se_squeeze (GlobalAvera (None, 32)           0           block1a_activation[0][0]
# __________________________________________________________________________________________________
# block1a_se_reshape (Reshape)    (None, 1, 1, 32)     0           block1a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block1a_se_reduce (Conv2D)      (None, 1, 1, 8)      264         block1a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block1a_se_expand (Conv2D)      (None, 1, 1, 32)     288         block1a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block1a_se_excite (Multiply)    (None, 112, 112, 32) 0           block1a_activation[0][0]
#                                                                  block1a_se_expand[0][0]
# __________________________________________________________________________________________________
# block1a_project_conv (Conv2D)   (None, 112, 112, 16) 512         block1a_se_excite[0][0]
# __________________________________________________________________________________________________
# block1a_project_bn (BatchNormal (None, 112, 112, 16) 64          block1a_project_conv[0][0]
# __________________________________________________________________________________________________
# block1b_dwconv (DepthwiseConv2D (None, 112, 112, 16) 144         block1a_project_bn[0][0]
# __________________________________________________________________________________________________
# block1b_bn (BatchNormalization) (None, 112, 112, 16) 64          block1b_dwconv[0][0]
# __________________________________________________________________________________________________
# block1b_activation (Activation) (None, 112, 112, 16) 0           block1b_bn[0][0]
# __________________________________________________________________________________________________
# block1b_se_squeeze (GlobalAvera (None, 16)           0           block1b_activation[0][0]
# __________________________________________________________________________________________________
# block1b_se_reshape (Reshape)    (None, 1, 1, 16)     0           block1b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block1b_se_reduce (Conv2D)      (None, 1, 1, 4)      68          block1b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block1b_se_expand (Conv2D)      (None, 1, 1, 16)     80          block1b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block1b_se_excite (Multiply)    (None, 112, 112, 16) 0           block1b_activation[0][0]
#                                                                  block1b_se_expand[0][0]
# __________________________________________________________________________________________________
# block1b_project_conv (Conv2D)   (None, 112, 112, 16) 256         block1b_se_excite[0][0]
# __________________________________________________________________________________________________
# block1b_project_bn (BatchNormal (None, 112, 112, 16) 64          block1b_project_conv[0][0]
# __________________________________________________________________________________________________
# block1b_drop (Dropout)          (None, 112, 112, 16) 0           block1b_project_bn[0][0]
# __________________________________________________________________________________________________
# block1b_add (Add)               (None, 112, 112, 16) 0           block1b_drop[0][0]
#                                                                  block1a_project_bn[0][0]
# __________________________________________________________________________________________________
# block2a_expand_conv (Conv2D)    (None, 112, 112, 96) 1536        block1b_add[0][0]
# __________________________________________________________________________________________________
# block2a_expand_bn (BatchNormali (None, 112, 112, 96) 384         block2a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2a_expand_activation (Acti (None, 112, 112, 96) 0           block2a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2a_dwconv_pad (ZeroPadding (None, 113, 113, 96) 0           block2a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2a_dwconv (DepthwiseConv2D (None, 56, 56, 96)   864         block2a_dwconv_pad[0][0]
# __________________________________________________________________________________________________
# block2a_bn (BatchNormalization) (None, 56, 56, 96)   384         block2a_dwconv[0][0]
# __________________________________________________________________________________________________
# block2a_activation (Activation) (None, 56, 56, 96)   0           block2a_bn[0][0]
# __________________________________________________________________________________________________
# block2a_se_squeeze (GlobalAvera (None, 96)           0           block2a_activation[0][0]
# __________________________________________________________________________________________________
# block2a_se_reshape (Reshape)    (None, 1, 1, 96)     0           block2a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2a_se_reduce (Conv2D)      (None, 1, 1, 4)      388         block2a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2a_se_expand (Conv2D)      (None, 1, 1, 96)     480         block2a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2a_se_excite (Multiply)    (None, 56, 56, 96)   0           block2a_activation[0][0]
#                                                                  block2a_se_expand[0][0]
# __________________________________________________________________________________________________
# block2a_project_conv (Conv2D)   (None, 56, 56, 24)   2304        block2a_se_excite[0][0]
# __________________________________________________________________________________________________
# block2a_project_bn (BatchNormal (None, 56, 56, 24)   96          block2a_project_conv[0][0]
# __________________________________________________________________________________________________
# block2b_expand_conv (Conv2D)    (None, 56, 56, 144)  3456        block2a_project_bn[0][0]
# __________________________________________________________________________________________________
# block2b_expand_bn (BatchNormali (None, 56, 56, 144)  576         block2b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2b_expand_activation (Acti (None, 56, 56, 144)  0           block2b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2b_dwconv (DepthwiseConv2D (None, 56, 56, 144)  1296        block2b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2b_bn (BatchNormalization) (None, 56, 56, 144)  576         block2b_dwconv[0][0]
# __________________________________________________________________________________________________
# block2b_activation (Activation) (None, 56, 56, 144)  0           block2b_bn[0][0]
# __________________________________________________________________________________________________
# block2b_se_squeeze (GlobalAvera (None, 144)          0           block2b_activation[0][0]
# __________________________________________________________________________________________________
# block2b_se_reshape (Reshape)    (None, 1, 1, 144)    0           block2b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2b_se_reduce (Conv2D)      (None, 1, 1, 6)      870         block2b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2b_se_expand (Conv2D)      (None, 1, 1, 144)    1008        block2b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2b_se_excite (Multiply)    (None, 56, 56, 144)  0           block2b_activation[0][0]
#                                                                  block2b_se_expand[0][0]
# __________________________________________________________________________________________________
# block2b_project_conv (Conv2D)   (None, 56, 56, 24)   3456        block2b_se_excite[0][0]
# __________________________________________________________________________________________________
# block2b_project_bn (BatchNormal (None, 56, 56, 24)   96          block2b_project_conv[0][0]
# __________________________________________________________________________________________________
# block2b_drop (Dropout)          (None, 56, 56, 24)   0           block2b_project_bn[0][0]
# __________________________________________________________________________________________________
# block2b_add (Add)               (None, 56, 56, 24)   0           block2b_drop[0][0]
#                                                                  block2a_project_bn[0][0]
# __________________________________________________________________________________________________
# block2c_expand_conv (Conv2D)    (None, 56, 56, 144)  3456        block2b_add[0][0]
# __________________________________________________________________________________________________
# block2c_expand_bn (BatchNormali (None, 56, 56, 144)  576         block2c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2c_expand_activation (Acti (None, 56, 56, 144)  0           block2c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2c_dwconv (DepthwiseConv2D (None, 56, 56, 144)  1296        block2c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2c_bn (BatchNormalization) (None, 56, 56, 144)  576         block2c_dwconv[0][0]
# __________________________________________________________________________________________________
# block2c_activation (Activation) (None, 56, 56, 144)  0           block2c_bn[0][0]
# __________________________________________________________________________________________________
# block2c_se_squeeze (GlobalAvera (None, 144)          0           block2c_activation[0][0]
# __________________________________________________________________________________________________
# block2c_se_reshape (Reshape)    (None, 1, 1, 144)    0           block2c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2c_se_reduce (Conv2D)      (None, 1, 1, 6)      870         block2c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2c_se_expand (Conv2D)      (None, 1, 1, 144)    1008        block2c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2c_se_excite (Multiply)    (None, 56, 56, 144)  0           block2c_activation[0][0]
#                                                                  block2c_se_expand[0][0]
# __________________________________________________________________________________________________
# block2c_project_conv (Conv2D)   (None, 56, 56, 24)   3456        block2c_se_excite[0][0]
# __________________________________________________________________________________________________
# block2c_project_bn (BatchNormal (None, 56, 56, 24)   96          block2c_project_conv[0][0]
# __________________________________________________________________________________________________
# block2c_drop (Dropout)          (None, 56, 56, 24)   0           block2c_project_bn[0][0]
# __________________________________________________________________________________________________
# block2c_add (Add)               (None, 56, 56, 24)   0           block2c_drop[0][0]
#                                                                  block2b_add[0][0]
# __________________________________________________________________________________________________
# block3a_expand_conv (Conv2D)    (None, 56, 56, 144)  3456        block2c_add[0][0]
# __________________________________________________________________________________________________
# block3a_expand_bn (BatchNormali (None, 56, 56, 144)  576         block3a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3a_expand_activation (Acti (None, 56, 56, 144)  0           block3a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3a_dwconv_pad (ZeroPadding (None, 59, 59, 144)  0           block3a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3a_dwconv (DepthwiseConv2D (None, 28, 28, 144)  3600        block3a_dwconv_pad[0][0]
# __________________________________________________________________________________________________
# block3a_bn (BatchNormalization) (None, 28, 28, 144)  576         block3a_dwconv[0][0]
# __________________________________________________________________________________________________
# block3a_activation (Activation) (None, 28, 28, 144)  0           block3a_bn[0][0]
# __________________________________________________________________________________________________
# block3a_se_squeeze (GlobalAvera (None, 144)          0           block3a_activation[0][0]
# __________________________________________________________________________________________________
# block3a_se_reshape (Reshape)    (None, 1, 1, 144)    0           block3a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3a_se_reduce (Conv2D)      (None, 1, 1, 6)      870         block3a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3a_se_expand (Conv2D)      (None, 1, 1, 144)    1008        block3a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3a_se_excite (Multiply)    (None, 28, 28, 144)  0           block3a_activation[0][0]
#                                                                  block3a_se_expand[0][0]
# __________________________________________________________________________________________________
# block3a_project_conv (Conv2D)   (None, 28, 28, 40)   5760        block3a_se_excite[0][0]
# __________________________________________________________________________________________________
# block3a_project_bn (BatchNormal (None, 28, 28, 40)   160         block3a_project_conv[0][0]
# __________________________________________________________________________________________________
# block3b_expand_conv (Conv2D)    (None, 28, 28, 240)  9600        block3a_project_bn[0][0]
# __________________________________________________________________________________________________
# block3b_expand_bn (BatchNormali (None, 28, 28, 240)  960         block3b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3b_expand_activation (Acti (None, 28, 28, 240)  0           block3b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3b_dwconv (DepthwiseConv2D (None, 28, 28, 240)  6000        block3b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3b_bn (BatchNormalization) (None, 28, 28, 240)  960         block3b_dwconv[0][0]
# __________________________________________________________________________________________________
# block3b_activation (Activation) (None, 28, 28, 240)  0           block3b_bn[0][0]
# __________________________________________________________________________________________________
# block3b_se_squeeze (GlobalAvera (None, 240)          0           block3b_activation[0][0]
# __________________________________________________________________________________________________
# block3b_se_reshape (Reshape)    (None, 1, 1, 240)    0           block3b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3b_se_reduce (Conv2D)      (None, 1, 1, 10)     2410        block3b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3b_se_expand (Conv2D)      (None, 1, 1, 240)    2640        block3b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3b_se_excite (Multiply)    (None, 28, 28, 240)  0           block3b_activation[0][0]
#                                                                  block3b_se_expand[0][0]
# __________________________________________________________________________________________________
# block3b_project_conv (Conv2D)   (None, 28, 28, 40)   9600        block3b_se_excite[0][0]
# __________________________________________________________________________________________________
# block3b_project_bn (BatchNormal (None, 28, 28, 40)   160         block3b_project_conv[0][0]
# __________________________________________________________________________________________________
# block3b_drop (Dropout)          (None, 28, 28, 40)   0           block3b_project_bn[0][0]
# __________________________________________________________________________________________________
# block3b_add (Add)               (None, 28, 28, 40)   0           block3b_drop[0][0]
#                                                                  block3a_project_bn[0][0]
# __________________________________________________________________________________________________
# block3c_expand_conv (Conv2D)    (None, 28, 28, 240)  9600        block3b_add[0][0]
# __________________________________________________________________________________________________
# block3c_expand_bn (BatchNormali (None, 28, 28, 240)  960         block3c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3c_expand_activation (Acti (None, 28, 28, 240)  0           block3c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3c_dwconv (DepthwiseConv2D (None, 28, 28, 240)  6000        block3c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3c_bn (BatchNormalization) (None, 28, 28, 240)  960         block3c_dwconv[0][0]
# __________________________________________________________________________________________________
# block3c_activation (Activation) (None, 28, 28, 240)  0           block3c_bn[0][0]
# __________________________________________________________________________________________________
# block3c_se_squeeze (GlobalAvera (None, 240)          0           block3c_activation[0][0]
# __________________________________________________________________________________________________
# block3c_se_reshape (Reshape)    (None, 1, 1, 240)    0           block3c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3c_se_reduce (Conv2D)      (None, 1, 1, 10)     2410        block3c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3c_se_expand (Conv2D)      (None, 1, 1, 240)    2640        block3c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3c_se_excite (Multiply)    (None, 28, 28, 240)  0           block3c_activation[0][0]
#                                                                  block3c_se_expand[0][0]
# __________________________________________________________________________________________________
# block3c_project_conv (Conv2D)   (None, 28, 28, 40)   9600        block3c_se_excite[0][0]
# __________________________________________________________________________________________________
# block3c_project_bn (BatchNormal (None, 28, 28, 40)   160         block3c_project_conv[0][0]
# __________________________________________________________________________________________________
# block3c_drop (Dropout)          (None, 28, 28, 40)   0           block3c_project_bn[0][0]
# __________________________________________________________________________________________________
# block3c_add (Add)               (None, 28, 28, 40)   0           block3c_drop[0][0]
#                                                                  block3b_add[0][0]
# __________________________________________________________________________________________________
# block4a_expand_conv (Conv2D)    (None, 28, 28, 240)  9600        block3c_add[0][0]
# __________________________________________________________________________________________________
# block4a_expand_bn (BatchNormali (None, 28, 28, 240)  960         block4a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4a_expand_activation (Acti (None, 28, 28, 240)  0           block4a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4a_dwconv_pad (ZeroPadding (None, 29, 29, 240)  0           block4a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4a_dwconv (DepthwiseConv2D (None, 14, 14, 240)  2160        block4a_dwconv_pad[0][0]
# __________________________________________________________________________________________________
# block4a_bn (BatchNormalization) (None, 14, 14, 240)  960         block4a_dwconv[0][0]
# __________________________________________________________________________________________________
# block4a_activation (Activation) (None, 14, 14, 240)  0           block4a_bn[0][0]
# __________________________________________________________________________________________________
# block4a_se_squeeze (GlobalAvera (None, 240)          0           block4a_activation[0][0]
# __________________________________________________________________________________________________
# block4a_se_reshape (Reshape)    (None, 1, 1, 240)    0           block4a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4a_se_reduce (Conv2D)      (None, 1, 1, 10)     2410        block4a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4a_se_expand (Conv2D)      (None, 1, 1, 240)    2640        block4a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4a_se_excite (Multiply)    (None, 14, 14, 240)  0           block4a_activation[0][0]
#                                                                  block4a_se_expand[0][0]
# __________________________________________________________________________________________________
# block4a_project_conv (Conv2D)   (None, 14, 14, 80)   19200       block4a_se_excite[0][0]
# __________________________________________________________________________________________________
# block4a_project_bn (BatchNormal (None, 14, 14, 80)   320         block4a_project_conv[0][0]
# __________________________________________________________________________________________________
# block4b_expand_conv (Conv2D)    (None, 14, 14, 480)  38400       block4a_project_bn[0][0]
# __________________________________________________________________________________________________
# block4b_expand_bn (BatchNormali (None, 14, 14, 480)  1920        block4b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4b_expand_activation (Acti (None, 14, 14, 480)  0           block4b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4b_dwconv (DepthwiseConv2D (None, 14, 14, 480)  4320        block4b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4b_bn (BatchNormalization) (None, 14, 14, 480)  1920        block4b_dwconv[0][0]
# __________________________________________________________________________________________________
# block4b_activation (Activation) (None, 14, 14, 480)  0           block4b_bn[0][0]
# __________________________________________________________________________________________________
# block4b_se_squeeze (GlobalAvera (None, 480)          0           block4b_activation[0][0]
# __________________________________________________________________________________________________
# block4b_se_reshape (Reshape)    (None, 1, 1, 480)    0           block4b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4b_se_reduce (Conv2D)      (None, 1, 1, 20)     9620        block4b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4b_se_expand (Conv2D)      (None, 1, 1, 480)    10080       block4b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4b_se_excite (Multiply)    (None, 14, 14, 480)  0           block4b_activation[0][0]
#                                                                  block4b_se_expand[0][0]
# __________________________________________________________________________________________________
# block4b_project_conv (Conv2D)   (None, 14, 14, 80)   38400       block4b_se_excite[0][0]
# __________________________________________________________________________________________________
# block4b_project_bn (BatchNormal (None, 14, 14, 80)   320         block4b_project_conv[0][0]
# __________________________________________________________________________________________________
# block4b_drop (Dropout)          (None, 14, 14, 80)   0           block4b_project_bn[0][0]
# __________________________________________________________________________________________________
# block4b_add (Add)               (None, 14, 14, 80)   0           block4b_drop[0][0]
#                                                                  block4a_project_bn[0][0]
# __________________________________________________________________________________________________
# block4c_expand_conv (Conv2D)    (None, 14, 14, 480)  38400       block4b_add[0][0]
# __________________________________________________________________________________________________
# block4c_expand_bn (BatchNormali (None, 14, 14, 480)  1920        block4c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4c_expand_activation (Acti (None, 14, 14, 480)  0           block4c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4c_dwconv (DepthwiseConv2D (None, 14, 14, 480)  4320        block4c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4c_bn (BatchNormalization) (None, 14, 14, 480)  1920        block4c_dwconv[0][0]
# __________________________________________________________________________________________________
# block4c_activation (Activation) (None, 14, 14, 480)  0           block4c_bn[0][0]
# __________________________________________________________________________________________________
# block4c_se_squeeze (GlobalAvera (None, 480)          0           block4c_activation[0][0]
# __________________________________________________________________________________________________
# block4c_se_reshape (Reshape)    (None, 1, 1, 480)    0           block4c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4c_se_reduce (Conv2D)      (None, 1, 1, 20)     9620        block4c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4c_se_expand (Conv2D)      (None, 1, 1, 480)    10080       block4c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4c_se_excite (Multiply)    (None, 14, 14, 480)  0           block4c_activation[0][0]
#                                                                  block4c_se_expand[0][0]
# __________________________________________________________________________________________________
# block4c_project_conv (Conv2D)   (None, 14, 14, 80)   38400       block4c_se_excite[0][0]
# __________________________________________________________________________________________________
# block4c_project_bn (BatchNormal (None, 14, 14, 80)   320         block4c_project_conv[0][0]
# __________________________________________________________________________________________________
# block4c_drop (Dropout)          (None, 14, 14, 80)   0           block4c_project_bn[0][0]
# __________________________________________________________________________________________________
# block4c_add (Add)               (None, 14, 14, 80)   0           block4c_drop[0][0]
#                                                                  block4b_add[0][0]
# __________________________________________________________________________________________________
# block4d_expand_conv (Conv2D)    (None, 14, 14, 480)  38400       block4c_add[0][0]
# __________________________________________________________________________________________________
# block4d_expand_bn (BatchNormali (None, 14, 14, 480)  1920        block4d_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4d_expand_activation (Acti (None, 14, 14, 480)  0           block4d_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4d_dwconv (DepthwiseConv2D (None, 14, 14, 480)  4320        block4d_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4d_bn (BatchNormalization) (None, 14, 14, 480)  1920        block4d_dwconv[0][0]
# __________________________________________________________________________________________________
# block4d_activation (Activation) (None, 14, 14, 480)  0           block4d_bn[0][0]
# __________________________________________________________________________________________________
# block4d_se_squeeze (GlobalAvera (None, 480)          0           block4d_activation[0][0]
# __________________________________________________________________________________________________
# block4d_se_reshape (Reshape)    (None, 1, 1, 480)    0           block4d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4d_se_reduce (Conv2D)      (None, 1, 1, 20)     9620        block4d_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4d_se_expand (Conv2D)      (None, 1, 1, 480)    10080       block4d_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4d_se_excite (Multiply)    (None, 14, 14, 480)  0           block4d_activation[0][0]
#                                                                  block4d_se_expand[0][0]
# __________________________________________________________________________________________________
# block4d_project_conv (Conv2D)   (None, 14, 14, 80)   38400       block4d_se_excite[0][0]
# __________________________________________________________________________________________________
# block4d_project_bn (BatchNormal (None, 14, 14, 80)   320         block4d_project_conv[0][0]
# __________________________________________________________________________________________________
# block4d_drop (Dropout)          (None, 14, 14, 80)   0           block4d_project_bn[0][0]
# __________________________________________________________________________________________________
# block4d_add (Add)               (None, 14, 14, 80)   0           block4d_drop[0][0]
#                                                                  block4c_add[0][0]
# __________________________________________________________________________________________________
# block5a_expand_conv (Conv2D)    (None, 14, 14, 480)  38400       block4d_add[0][0]
# __________________________________________________________________________________________________
# block5a_expand_bn (BatchNormali (None, 14, 14, 480)  1920        block5a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block5a_expand_activation (Acti (None, 14, 14, 480)  0           block5a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block5a_dwconv (DepthwiseConv2D (None, 14, 14, 480)  12000       block5a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block5a_bn (BatchNormalization) (None, 14, 14, 480)  1920        block5a_dwconv[0][0]
# __________________________________________________________________________________________________
# block5a_activation (Activation) (None, 14, 14, 480)  0           block5a_bn[0][0]
# __________________________________________________________________________________________________
# block5a_se_squeeze (GlobalAvera (None, 480)          0           block5a_activation[0][0]
# __________________________________________________________________________________________________
# block5a_se_reshape (Reshape)    (None, 1, 1, 480)    0           block5a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block5a_se_reduce (Conv2D)      (None, 1, 1, 20)     9620        block5a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block5a_se_expand (Conv2D)      (None, 1, 1, 480)    10080       block5a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block5a_se_excite (Multiply)    (None, 14, 14, 480)  0           block5a_activation[0][0]
#                                                                  block5a_se_expand[0][0]
# __________________________________________________________________________________________________
# block5a_project_conv (Conv2D)   (None, 14, 14, 112)  53760       block5a_se_excite[0][0]
# __________________________________________________________________________________________________
# block5a_project_bn (BatchNormal (None, 14, 14, 112)  448         block5a_project_conv[0][0]
# __________________________________________________________________________________________________
# block5b_expand_conv (Conv2D)    (None, 14, 14, 672)  75264       block5a_project_bn[0][0]
# __________________________________________________________________________________________________
# block5b_expand_bn (BatchNormali (None, 14, 14, 672)  2688        block5b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block5b_expand_activation (Acti (None, 14, 14, 672)  0           block5b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block5b_dwconv (DepthwiseConv2D (None, 14, 14, 672)  16800       block5b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block5b_bn (BatchNormalization) (None, 14, 14, 672)  2688        block5b_dwconv[0][0]
# __________________________________________________________________________________________________
# block5b_activation (Activation) (None, 14, 14, 672)  0           block5b_bn[0][0]
# __________________________________________________________________________________________________
# block5b_se_squeeze (GlobalAvera (None, 672)          0           block5b_activation[0][0]
# __________________________________________________________________________________________________
# block5b_se_reshape (Reshape)    (None, 1, 1, 672)    0           block5b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block5b_se_reduce (Conv2D)      (None, 1, 1, 28)     18844       block5b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block5b_se_expand (Conv2D)      (None, 1, 1, 672)    19488       block5b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block5b_se_excite (Multiply)    (None, 14, 14, 672)  0           block5b_activation[0][0]
#                                                                  block5b_se_expand[0][0]
# __________________________________________________________________________________________________
# block5b_project_conv (Conv2D)   (None, 14, 14, 112)  75264       block5b_se_excite[0][0]
# __________________________________________________________________________________________________
# block5b_project_bn (BatchNormal (None, 14, 14, 112)  448         block5b_project_conv[0][0]
# __________________________________________________________________________________________________
# block5b_drop (Dropout)          (None, 14, 14, 112)  0           block5b_project_bn[0][0]
# __________________________________________________________________________________________________
# block5b_add (Add)               (None, 14, 14, 112)  0           block5b_drop[0][0]
#                                                                  block5a_project_bn[0][0]
# __________________________________________________________________________________________________
# block5c_expand_conv (Conv2D)    (None, 14, 14, 672)  75264       block5b_add[0][0]
# __________________________________________________________________________________________________
# block5c_expand_bn (BatchNormali (None, 14, 14, 672)  2688        block5c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block5c_expand_activation (Acti (None, 14, 14, 672)  0           block5c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block5c_dwconv (DepthwiseConv2D (None, 14, 14, 672)  16800       block5c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block5c_bn (BatchNormalization) (None, 14, 14, 672)  2688        block5c_dwconv[0][0]
# __________________________________________________________________________________________________
# block5c_activation (Activation) (None, 14, 14, 672)  0           block5c_bn[0][0]
# __________________________________________________________________________________________________
# block5c_se_squeeze (GlobalAvera (None, 672)          0           block5c_activation[0][0]
# __________________________________________________________________________________________________
# block5c_se_reshape (Reshape)    (None, 1, 1, 672)    0           block5c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block5c_se_reduce (Conv2D)      (None, 1, 1, 28)     18844       block5c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block5c_se_expand (Conv2D)      (None, 1, 1, 672)    19488       block5c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block5c_se_excite (Multiply)    (None, 14, 14, 672)  0           block5c_activation[0][0]
#                                                                  block5c_se_expand[0][0]
# __________________________________________________________________________________________________
# block5c_project_conv (Conv2D)   (None, 14, 14, 112)  75264       block5c_se_excite[0][0]
# __________________________________________________________________________________________________
# block5c_project_bn (BatchNormal (None, 14, 14, 112)  448         block5c_project_conv[0][0]
# __________________________________________________________________________________________________
# block5c_drop (Dropout)          (None, 14, 14, 112)  0           block5c_project_bn[0][0]
# __________________________________________________________________________________________________
# block5c_add (Add)               (None, 14, 14, 112)  0           block5c_drop[0][0]
#                                                                  block5b_add[0][0]
# __________________________________________________________________________________________________
# block5d_expand_conv (Conv2D)    (None, 14, 14, 672)  75264       block5c_add[0][0]
# __________________________________________________________________________________________________
# block5d_expand_bn (BatchNormali (None, 14, 14, 672)  2688        block5d_expand_conv[0][0]
# __________________________________________________________________________________________________
# block5d_expand_activation (Acti (None, 14, 14, 672)  0           block5d_expand_bn[0][0]
# __________________________________________________________________________________________________
# block5d_dwconv (DepthwiseConv2D (None, 14, 14, 672)  16800       block5d_expand_activation[0][0]
# __________________________________________________________________________________________________
# block5d_bn (BatchNormalization) (None, 14, 14, 672)  2688        block5d_dwconv[0][0]
# __________________________________________________________________________________________________
# block5d_activation (Activation) (None, 14, 14, 672)  0           block5d_bn[0][0]
# __________________________________________________________________________________________________
# block5d_se_squeeze (GlobalAvera (None, 672)          0           block5d_activation[0][0]
# __________________________________________________________________________________________________
# block5d_se_reshape (Reshape)    (None, 1, 1, 672)    0           block5d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# block6c_dwconv (DepthwiseConv2D (None, 7, 7, 1152)   28800       block6c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block6c_bn (BatchNormalization) (None, 7, 7, 1152)   4608        block6c_dwconv[0][0]
# __________________________________________________________________________________________________
# block6c_activation (Activation) (None, 7, 7, 1152)   0           block6c_bn[0][0]
# __________________________________________________________________________________________________
# block6c_se_squeeze (GlobalAvera (None, 1152)         0           block6c_activation[0][0]
# __________________________________________________________________________________________________
# block6c_se_reshape (Reshape)    (None, 1, 1, 1152)   0           block6c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block6c_se_reduce (Conv2D)      (None, 1, 1, 48)     55344       block6c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block6c_se_expand (Conv2D)      (None, 1, 1, 1152)   56448       block6c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block6c_se_excite (Multiply)    (None, 7, 7, 1152)   0           block6c_activation[0][0]
#                                                                  block6c_se_expand[0][0]
# __________________________________________________________________________________________________
# block6c_project_conv (Conv2D)   (None, 7, 7, 192)    221184      block6c_se_excite[0][0]
# __________________________________________________________________________________________________
# block6c_project_bn (BatchNormal (None, 7, 7, 192)    768         block6c_project_conv[0][0]
# __________________________________________________________________________________________________
# block6c_drop (Dropout)          (None, 7, 7, 192)    0           block6c_project_bn[0][0]
# __________________________________________________________________________________________________
# block6c_add (Add)               (None, 7, 7, 192)    0           block6c_drop[0][0]
#                                                                  block6b_add[0][0]
# __________________________________________________________________________________________________
# block6d_expand_conv (Conv2D)    (None, 7, 7, 1152)   221184      block6c_add[0][0]
# __________________________________________________________________________________________________
# block6d_expand_bn (BatchNormali (None, 7, 7, 1152)   4608        block6d_expand_conv[0][0]
# __________________________________________________________________________________________________
# block6d_expand_activation (Acti (None, 7, 7, 1152)   0           block6d_expand_bn[0][0]
# __________________________________________________________________________________________________
# block6d_dwconv (DepthwiseConv2D (None, 7, 7, 1152)   28800       block6d_expand_activation[0][0]
# __________________________________________________________________________________________________
# block6d_bn (BatchNormalization) (None, 7, 7, 1152)   4608        block6d_dwconv[0][0]
# __________________________________________________________________________________________________
# block6d_activation (Activation) (None, 7, 7, 1152)   0           block6d_bn[0][0]
# __________________________________________________________________________________________________
# block6d_se_squeeze (GlobalAvera (None, 1152)         0           block6d_activation[0][0]
# __________________________________________________________________________________________________
# block6d_se_reshape (Reshape)    (None, 1, 1, 1152)   0           block6d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block6d_se_reduce (Conv2D)      (None, 1, 1, 48)     55344       block6d_se_reshape[0][0]
# __________________________________________________________________________________________________
# block6d_se_expand (Conv2D)      (None, 1, 1, 1152)   56448       block6d_se_reduce[0][0]
# __________________________________________________________________________________________________
# block6d_se_excite (Multiply)    (None, 7, 7, 1152)   0           block6d_activation[0][0]
#                                                                  block6d_se_expand[0][0]
# __________________________________________________________________________________________________
# block6d_project_conv (Conv2D)   (None, 7, 7, 192)    221184      block6d_se_excite[0][0]
# __________________________________________________________________________________________________
# block6d_project_bn (BatchNormal (None, 7, 7, 192)    768         block6d_project_conv[0][0]
# __________________________________________________________________________________________________
# block6d_drop (Dropout)          (None, 7, 7, 192)    0           block6d_project_bn[0][0]
# __________________________________________________________________________________________________
# block6d_add (Add)               (None, 7, 7, 192)    0           block6d_drop[0][0]
#                                                                  block6c_add[0][0]
# __________________________________________________________________________________________________
# block6e_expand_conv (Conv2D)    (None, 7, 7, 1152)   221184      block6d_add[0][0]
# __________________________________________________________________________________________________
# block6e_expand_bn (BatchNormali (None, 7, 7, 1152)   4608        block6e_expand_conv[0][0]
# __________________________________________________________________________________________________
# block6e_expand_activation (Acti (None, 7, 7, 1152)   0           block6e_expand_bn[0][0]
# __________________________________________________________________________________________________
# block6e_dwconv (DepthwiseConv2D (None, 7, 7, 1152)   28800       block6e_expand_activation[0][0]
# __________________________________________________________________________________________________
# block6e_bn (BatchNormalization) (None, 7, 7, 1152)   4608        block6e_dwconv[0][0]
# __________________________________________________________________________________________________
# block6e_activation (Activation) (None, 7, 7, 1152)   0           block6e_bn[0][0]
# __________________________________________________________________________________________________
# block6e_se_squeeze (GlobalAvera (None, 1152)         0           block6e_activation[0][0]
# __________________________________________________________________________________________________
# block6e_se_reshape (Reshape)    (None, 1, 1, 1152)   0           block6e_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block6e_se_reduce (Conv2D)      (None, 1, 1, 48)     55344       block6e_se_reshape[0][0]
# __________________________________________________________________________________________________
# block6e_se_expand (Conv2D)      (None, 1, 1, 1152)   56448       block6e_se_reduce[0][0]
# __________________________________________________________________________________________________
# block6e_se_excite (Multiply)    (None, 7, 7, 1152)   0           block6e_activation[0][0]
#                                                                  block6e_se_expand[0][0]
# __________________________________________________________________________________________________
# block6e_project_conv (Conv2D)   (None, 7, 7, 192)    221184      block6e_se_excite[0][0]
# __________________________________________________________________________________________________
# block6e_project_bn (BatchNormal (None, 7, 7, 192)    768         block6e_project_conv[0][0]
# __________________________________________________________________________________________________
# block6e_drop (Dropout)          (None, 7, 7, 192)    0           block6e_project_bn[0][0]
# __________________________________________________________________________________________________
# block6e_add (Add)               (None, 7, 7, 192)    0           block6e_drop[0][0]
#                                                                  block6d_add[0][0]
# __________________________________________________________________________________________________
# block7a_expand_conv (Conv2D)    (None, 7, 7, 1152)   221184      block6e_add[0][0]
# __________________________________________________________________________________________________
# block7a_expand_bn (BatchNormali (None, 7, 7, 1152)   4608        block7a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block7a_expand_activation (Acti (None, 7, 7, 1152)   0           block7a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block7a_dwconv (DepthwiseConv2D (None, 7, 7, 1152)   10368       block7a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block7a_bn (BatchNormalization) (None, 7, 7, 1152)   4608        block7a_dwconv[0][0]
# __________________________________________________________________________________________________
# block7a_activation (Activation) (None, 7, 7, 1152)   0           block7a_bn[0][0]
# __________________________________________________________________________________________________
# block7a_se_squeeze (GlobalAvera (None, 1152)         0           block7a_activation[0][0]
# __________________________________________________________________________________________________
# block7a_se_reshape (Reshape)    (None, 1, 1, 1152)   0           block7a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block7a_se_reduce (Conv2D)      (None, 1, 1, 48)     55344       block7a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block7a_se_expand (Conv2D)      (None, 1, 1, 1152)   56448       block7a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block7a_se_excite (Multiply)    (None, 7, 7, 1152)   0           block7a_activation[0][0]
#                                                                  block7a_se_expand[0][0]
# __________________________________________________________________________________________________
# block7a_project_conv (Conv2D)   (None, 7, 7, 320)    368640      block7a_se_excite[0][0]
# __________________________________________________________________________________________________
# block7a_project_bn (BatchNormal (None, 7, 7, 320)    1280        block7a_project_conv[0][0]
# __________________________________________________________________________________________________
# block7b_expand_conv (Conv2D)    (None, 7, 7, 1920)   614400      block7a_project_bn[0][0]
# __________________________________________________________________________________________________
# block7b_expand_bn (BatchNormali (None, 7, 7, 1920)   7680        block7b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block7b_expand_activation (Acti (None, 7, 7, 1920)   0           block7b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block7b_dwconv (DepthwiseConv2D (None, 7, 7, 1920)   17280       block7b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block7b_bn (BatchNormalization) (None, 7, 7, 1920)   7680        block7b_dwconv[0][0]
# __________________________________________________________________________________________________
# block7b_activation (Activation) (None, 7, 7, 1920)   0           block7b_bn[0][0]
# __________________________________________________________________________________________________
# block7b_se_squeeze (GlobalAvera (None, 1920)         0           block7b_activation[0][0]
# __________________________________________________________________________________________________
# block7b_se_reshape (Reshape)    (None, 1, 1, 1920)   0           block7b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block7b_se_reduce (Conv2D)      (None, 1, 1, 80)     153680      block7b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block7b_se_expand (Conv2D)      (None, 1, 1, 1920)   155520      block7b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block7b_se_excite (Multiply)    (None, 7, 7, 1920)   0           block7b_activation[0][0]
#                                                                  block7b_se_expand[0][0]
# __________________________________________________________________________________________________
# block7b_project_conv (Conv2D)   (None, 7, 7, 320)    614400      block7b_se_excite[0][0]
# __________________________________________________________________________________________________
# block7b_project_bn (BatchNormal (None, 7, 7, 320)    1280        block7b_project_conv[0][0]
# __________________________________________________________________________________________________
# block7b_drop (Dropout)          (None, 7, 7, 320)    0           block7b_project_bn[0][0]
# __________________________________________________________________________________________________
# block7b_add (Add)               (None, 7, 7, 320)    0           block7b_drop[0][0]
#                                                                  block7a_project_bn[0][0]
# __________________________________________________________________________________________________
# top_conv (Conv2D)               (None, 7, 7, 1280)   409600      block7b_add[0][0]
# __________________________________________________________________________________________________
# top_bn (BatchNormalization)     (None, 7, 7, 1280)   5120        top_conv[0][0]
# __________________________________________________________________________________________________
# top_activation (Activation)     (None, 7, 7, 1280)   0           top_bn[0][0]
# ==================================================================================================
# Total params: 6,575,239
# Trainable params: 6,513,184
# Non-trainable params: 62,055
# __________________________________________________________________________________________________
# Found 41345 images belonging to 2 classes.
# Found 20930 images belonging to 2 classes.
# weights ratio to make the dataset balanced:  {0: 0.684089480128396, 1: 1.858035232788064}
# class Indices of train generator : {'Epithelioid': 0, 'Nonepithelioid': 1}
# class Indices of validation generator : {'Epithelioid': 0, 'Nonepithelioid': 1}

# %%
def training_model(pretrained_model,final_activation):
    model = Sequential()
    model.add(pretrained_model) #pretrained model
    model.add(Flatten()) #creating a single 1-d vector
    model.add(Dense(2,activation=final_activation))#output layer with softmax activation function.
    return model

#this function takes the each patch in WSI then predicts the probability score
def pred_each_patch(path,name):
    y = image.load_img(os.path.join(path, name))
    img = image.img_to_array(y)
    y = np.expand_dims(img, axis = 0)
    y /= 255
    y_pred = model.predict(y)
    return y_pred
        
def avg(predlist):
    average = sum(predlist)/len(predlist)
    return average

def extract_index_one_frmpred(prediction_list):               
    ypred = np.stack(prediction_list)#we are vertically stacking the predictions
    ypred = np.reshape(ypred, [len(prediction_list),2])#reshaping to 100,2 - np array
    for each in ypred:
    #after reshaping the predictions as we wanted, we are taking the index '1' to compute whole slide level AUC-ROC
        val = each[1]
        pred_prob_list.append(val)#appending all the values into a list - to compute average values of single WSI and maximum of single WSI.
        
    return pred_prob_list
    
def plt_history(history): 
    
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epochs')
    plt.legend(['train', 'validation'], loc='upper right')
    plt.tight_layout() 
    plt.show()
    return

def y_labels(path):
  if "Epithelioid" in path:
    y_test_labels.append(0.0)
  elif "Nonepithelioid" in path:
    y_test_labels.append(1.0) 
  return

def prediction_scores(y_test_labels,AVG_LIST_PREDICTIONS,MAX_LIST_PREDICTIONS):
  #AUC - ROC score
  false_pr_avg,true_pr_avg,threshold = roc_curve(y_test_labels,AVG_LIST_PREDICTIONS)
  roc_auc_avg = auc(false_pr_avg,true_pr_avg)
  print("AUC - ROC on Test data average prediction scores:",roc_auc_avg)
  print("-----------------------------------------------------")
  plt.plot(false_pr_avg,true_pr_avg,color='green',label='ROC curve on test data(area = %0.2f)' %(auc(false_pr_avg,true_pr_avg)))
  plt.plot([0, 1], [0, 1], color='navy', linestyle='--',label = 'Random')
  plt.xlabel("False positive rate")
  plt.ylabel("True positive rate")
  plt.title('ROC curve on Test data (area = %0.2f)' %(auc(false_pr_avg,true_pr_avg)))
  plt.legend(loc = "lower right")
  plt.tight_layout()
  plt.show()
  
  false_pr_max,true_pr_max,threshold = roc_curve(y_test_labels,MAX_LIST_PREDICTIONS)
  roc_auc_max = auc(false_pr_max,true_pr_max)
  print("AUC - ROC on Test data maximum prediction scores:",roc_auc_max)
  print("-----------------------------------------------------")
  plt.plot(false_pr_max,true_pr_max,color='magenta',label='ROC curve on test data(area = %0.2f)' %(auc(false_pr_max,true_pr_max)))
  plt.plot([0, 1], [0, 1], color='navy', linestyle='--',label = 'Random')
  plt.xlabel("False positive rate")
  plt.ylabel("True positive rate")
  plt.title('ROC curve on Test data (area = %0.2f)' %(auc(false_pr_max,true_pr_max)))
  plt.legend(loc = "lower right")
  plt.tight_layout()
  plt.show()
 

def pre_recall(y_test_labels,AVG_LIST_PREDICTIONS,MAX_LIST_PREDICTIONS):
  #presicion - recall curve
  precision, recall, threshold = precision_recall_curve(y_test_labels,AVG_LIST_PREDICTIONS)
  print("Presicion - Recall auc on test data average score predictions:",auc(recall,precision))
 
  print("-----------------------------------------------------")
  plt.plot(precision, recall,color='orange',label='PR curve (area = %0.2f)' %(auc(recall,precision)))
  plt.xlabel("Recall")
  plt.ylabel("Precision")
  plt.title('Presicion Recall curve on Test data (area = %0.2f)' %(auc(recall,precision)))
  plt.legend(loc = "lower right")
  plt.tight_layout()
  plt.show()

  precision_max, recall_max, threshold = precision_recall_curve(y_test_labels,MAX_LIST_PREDICTIONS)
  print("Presicion - Recall auc on test data maximum score predictions:",auc(recall_max,precision_max))
 
  print("-----------------------------------------------------")
  plt.plot(precision_max, recall_max,color='cyan',label='PR curve (area = %0.2f)' %(auc(recall_max,precision_max)))
  plt.xlabel("Recall")
  plt.ylabel("Precision")
  plt.title('Presicion Recall curve on Test data (area = %0.2f)' %(auc(recall_max,precision_max)))
  plt.legend(loc = "lower right")
  plt.tight_layout()
  plt.show()

# %%
from keras.models import load_model

model = training_model(base_model,final_activation)  

reduce_lr = keras.callbacks.ReduceLROnPlateau(monitor = 'val_loss',factor = 0.1,patience=3,verbose = 1)
# early stopping is to prevent overfitting
es = EarlyStopping(monitor='val_loss',verbose=1, patience=patience)

opt_nadam = tf.keras.optimizers.Nadam(1e-4)#Adam with Nestrov momentum

model.compile(optimizer= opt_nadam, loss=loss_function,metrics = [tf.keras.metrics.AUC(),tf.keras.metrics.Precision(),tf.keras.metrics.Recall()])


#Initilaising the model
history = model.fit(train_data_generator, steps_per_epoch=len(train_data_generator.classes)//batch_size, validation_data=val_data_generator,epochs = epoch,class_weight = weights,callbacks =[es,reduce_lr],workers = 4)
    
plt_history(history)#model_loss_plot
# Out:
# Epoch 1/50
# 646/646 [==============================] - 447s 692ms/step - loss: 0.5948 - auc: 0.8045 - precision: 0.7238 - recall: 0.7238 - val_loss: 0.9691 - val_auc: 0.4547 - val_precision: 0.4626 - val_recall: 0.4626
# Epoch 2/50
# 646/646 [==============================] - 443s 686ms/step - loss: 0.2987 - auc: 0.9467 - precision: 0.8716 - recall: 0.8716 - val_loss: 0.8980 - val_auc: 0.5649 - val_precision: 0.5417 - val_recall: 0.5417
# Epoch 3/50
# 646/646 [==============================] - 443s 686ms/step - loss: 0.1975 - auc: 0.9754 - precision: 0.9180 - recall: 0.9180 - val_loss: 0.9683 - val_auc: 0.5939 - val_precision: 0.5672 - val_recall: 0.5672
# Epoch 4/50
# 646/646 [==============================] - 443s 686ms/step - loss: 0.1575 - auc: 0.9841 - precision: 0.9360 - recall: 0.9360 - val_loss: 1.2983 - val_auc: 0.5867 - val_precision: 0.5564 - val_recall: 0.5564
# Epoch 5/50
# 646/646 [==============================] - ETA: 0s - loss: 0.1024 - auc: 0.9929 - precision: 0.9592 - recall: 0.9592
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 646/646 [==============================] - 443s 686ms/step - loss: 0.1024 - auc: 0.9929 - precision: 0.9592 - recall: 0.9592 - val_loss: 1.6083 - val_auc: 0.5477 - val_precision: 0.5339 - val_recall: 0.5339
# Epoch 6/50
# 646/646 [==============================] - 443s 685ms/step - loss: 0.0666 - auc: 0.9969 - precision: 0.9736 - recall: 0.9736 - val_loss: 1.9887 - val_auc: 0.6839 - val_precision: 0.6439 - val_recall: 0.6439
# Epoch 7/50
# 646/646 [==============================] - 442s 685ms/step - loss: 0.0612 - auc: 0.9975 - precision: 0.9782 - recall: 0.9782 - val_loss: 1.9520 - val_auc: 0.6803 - val_precision: 0.6405 - val_recall: 0.6405
# Epoch 8/50
# 646/646 [==============================] - ETA: 0s - loss: 0.0498 - auc: 0.9984 - precision: 0.9820 - recall: 0.9820
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 646/646 [==============================] - 443s 686ms/step - loss: 0.0498 - auc: 0.9984 - precision: 0.9820 - recall: 0.9820 - val_loss: 1.6193 - val_auc: 0.6730 - val_precision: 0.6276 - val_recall: 0.6276
# Epoch 9/50
# 646/646 [==============================] - 442s 685ms/step - loss: 0.0480 - auc: 0.9983 - precision: 0.9828 - recall: 0.9828 - val_loss: 1.8812 - val_auc: 0.6743 - val_precision: 0.6341 - val_recall: 0.6341
# Epoch 10/50
# 646/646 [==============================] - 442s 685ms/step - loss: 0.0417 - auc: 0.9988 - precision: 0.9848 - recall: 0.9848 - val_loss: 1.9088 - val_auc: 0.6800 - val_precision: 0.6405 - val_recall: 0.6405
# Epoch 11/50
# 646/646 [==============================] - ETA: 0s - loss: 0.0440 - auc: 0.9988 - precision: 0.9844 - recall: 0.9844
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
# 646/646 [==============================] - 443s 685ms/step - loss: 0.0440 - auc: 0.9988 - precision: 0.9844 - recall: 0.9844 - val_loss: 1.8586 - val_auc: 0.6805 - val_precision: 0.6407 - val_recall: 0.6407
# Epoch 12/50
# 646/646 [==============================] - 442s 684ms/step - loss: 0.0427 - auc: 0.9988 - precision: 0.9851 - recall: 0.9851 - val_loss: 1.9154 - val_auc: 0.6804 - val_precision: 0.6415 - val_recall: 0.6415
# Epoch 00012: early stopping

# %%
AVG_LIST_PREDICTIONS = []
MAX_LIST_PREDICTIONS = []
y_test_labels= []
print("Prediction on test using aggregation method")
for path, subdirs, files in os.walk(test_path): #iterating through folders of each WSI
    if(fnmatch(path,folder_pattern)):
        WSI_pred = list()
        pred_prob_list = list()
        # print("Iterating through all the patches in: ",os.path.basename(os.path.normpath(path)))
        y_labels(path)

        for name in files:
          if fnmatch(name, file_pattern):#iterating through each patch in all WSI image and computing probabilities
              prediction = pred_each_patch(path,name)
              WSI_pred.append(prediction)#this list contains probabilities of all patches in testset images

        #computing average and maximum prediction of each image - so that we can compute Whole slide level AUC - ROC than patch level
        predictions = extract_index_one_frmpred(WSI_pred)
        #This list contains average score of all 36 test set images
        AVG_LIST_PREDICTIONS.append(avg(predictions))
        MAX_LIST_PREDICTIONS.append(max(predictions))
# Out:
# Prediction on test using aggregation method

# %%
#saving the actual labels and predictions into cvs files for futher use
import pandas as pd

df = pd.DataFrame()
df['Average'] = AVG_LIST_PREDICTIONS
df['Maximum'] = MAX_LIST_PREDICTIONS
df['Actual Labels'] = y_test_labels
df.to_csv('FOLD3_500_efficient_test.csv',index = False,header = True)

# !cp FOLD3_500_efficient_test.csv "drive/My Drive/"

# %% [markdown]
# **AUC-ROC curves**

# %%
prediction_scores(y_test_labels,AVG_LIST_PREDICTIONS,MAX_LIST_PREDICTIONS)
# Out:
# AUC - ROC on Test data average prediction scores: 0.7654320987654322
# -----------------------------------------------------
# AUC - ROC on Test data maximum prediction scores: 0.6275720164609053
# -----------------------------------------------------

# %% [markdown]
# **Presicion recall curves**

# %%
pre_recall(y_test_labels,AVG_LIST_PREDICTIONS,MAX_LIST_PREDICTIONS)
# Out:
# Presicion - Recall auc on test data average score predictions: 0.49997609862273124
# -----------------------------------------------------
# Presicion - Recall auc on test data maximum score predictions: 0.512058992381573
# -----------------------------------------------------

# %% [markdown]
# **Classification reports**

# %%
from sklearn.metrics import classification_report

AVG_LIST_PREDICTIONS = [round(x) for x in AVG_LIST_PREDICTIONS]
print("CLASSIFICATION REPORT for AVERAGE SCORE PREDICTIONS")
print(classification_report(y_test_labels,AVG_LIST_PREDICTIONS))
# Out:
# CLASSIFICATION REPORT for AVERAGE SCORE PREDICTIONS
#               precision    recall  f1-score   support
#
#          0.0       0.82      0.85      0.84        27
#          1.0       0.50      0.44      0.47         9
#
#     accuracy                           0.75        36
#    macro avg       0.66      0.65      0.65        36
# weighted avg       0.74      0.75      0.74        36

# %%
MAX_LIST_PREDICTIONS = [round(x) for x in MAX_LIST_PREDICTIONS]
print("CLASSIFICATION REPORT for MAX VALUE PREDICTIONS")
print(classification_report(y_test_labels,MAX_LIST_PREDICTIONS))
# Out:
# CLASSIFICATION REPORT for MAX VALUE PREDICTIONS
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00        27
#          1.0       0.25      1.00      0.40         9
#
#     accuracy                           0.25        36
#    macro avg       0.12      0.50      0.20        36
# weighted avg       0.06      0.25      0.10        36
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# **PREDICTIONS ON VALIDATION DATA USING AGGREGATION METHOD**

# %%
AVG_LIST_PREDICTIONS_VAL = []
MAX_LIST_PREDICTIONS_VAL = []
y_val_labels= []
print("Prediction on validation using aggregation method")
for path, subdirs, files in os.walk(val_path): #iterating through folders of each WSI
    if(fnmatch(path,folder_pattern)):
        WSI_pred = list()
        pred_prob_list = list()
        # print("Iterating through all the patches in: ",os.path.basename(os.path.normpath(path)))
        if "Epithelioid" in path:
          y_val_labels.append(0.0)
        elif "Nonepithelioid" in path:
          y_val_labels.append(1.0) 

        for name in files:
          if fnmatch(name, file_pattern):#iterating through each patch in all WSI image and computing probabilities
              prediction = pred_each_patch(path,name)
              WSI_pred.append(prediction)#this list contains probabilities of all patches in testset images

        #computing average and maximum prediction of each image - so that we can compute Whole slide level AUC - ROC than patch level
        predictions = extract_index_one_frmpred(WSI_pred)
        #This list contains average score of all 36 test set images
        AVG_LIST_PREDICTIONS_VAL.append(avg(predictions))
        MAX_LIST_PREDICTIONS_VAL.append(max(predictions))
# Out:
# Prediction on validation using aggregation method

# %%
#saving the validation predictions

df_val = pd.DataFrame()
df_val['Average'] = AVG_LIST_PREDICTIONS_VAL
df_val['Maximum'] = MAX_LIST_PREDICTIONS_VAL
df_val['Actual labels'] = y_val_labels
df_val.to_csv('FOLD3_500_efficient_val.csv',index = False,header = True)

# !cp FOLD3_500_efficient_val.csv "drive/My Drive/"

# %%
#AUC-ROC Curves
false_pr_avg,true_pr_avg,threshold = roc_curve(y_val_labels,AVG_LIST_PREDICTIONS_VAL)
roc_auc_avg = auc(false_pr_avg,true_pr_avg)
print("AUC - ROC on validation data average prediction scores:",roc_auc_avg)
print("-----------------------------------------------------")
plt.plot(false_pr_avg,true_pr_avg,color='green',label='ROC curve on validation data(area = %0.2f)' %(auc(false_pr_avg,true_pr_avg)))
plt.plot([0, 1], [0, 1], color='navy', linestyle='--',label = 'Random')
plt.xlabel("False positive rate")
plt.ylabel("True positive rate")
plt.title('ROC curve on validation data (area = %0.2f)' %(auc(false_pr_avg,true_pr_avg)))
plt.legend(loc = "lower right")
plt.tight_layout()
plt.show()
  
false_pr_max,true_pr_max,threshold = roc_curve(y_val_labels,MAX_LIST_PREDICTIONS_VAL)
roc_auc_max = auc(false_pr_max,true_pr_max)
print("AUC - ROC on validation data maximum prediction scores:",roc_auc_max)
print("-----------------------------------------------------")
plt.plot(false_pr_max,true_pr_max,color='magenta',label='ROC curve on validation data(area = %0.2f)' %(auc(false_pr_max,true_pr_max)))
plt.plot([0, 1], [0, 1], color='navy', linestyle='--',label = 'Random')
plt.xlabel("False positive rate")
plt.ylabel("True positive rate")
plt.title('ROC curve on validation data (area = %0.2f)' %(auc(false_pr_max,true_pr_max)))
plt.legend(loc = "lower right")
plt.tight_layout()
plt.show()
# Out:
# AUC - ROC on validation data average prediction scores: 0.5291375291375291
# -----------------------------------------------------
# AUC - ROC on validation data maximum prediction scores: 0.585081585081585
# -----------------------------------------------------

# %%
#presicion - recall curve
precision, recall, threshold = precision_recall_curve(y_val_labels,AVG_LIST_PREDICTIONS_VAL)
print("Presicion - Recall auc on validation data average score predictions:",auc(recall,precision))
 
print("-----------------------------------------------------")
plt.plot(precision, recall,color='red',label='PR curve (area = %0.2f)' %(auc(recall,precision)))
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title('Presicion Recall curve on validation data (area = %0.2f)' %(auc(recall,precision)))
plt.legend(loc = "lower right")
plt.tight_layout()
plt.show()

precision_max, recall_max, threshold = precision_recall_curve(y_val_labels,MAX_LIST_PREDICTIONS_VAL)
print("Presicion - Recall auc on validation data maximum score predictions:",auc(recall_max,precision_max))
print("-----------------------------------------------------")
plt.plot(precision_max, recall_max,color='blue',label='PR curve (area = %0.2f)' %(auc(recall_max,precision_max)))
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title('Presicion Recall curve on validation data (area = %0.2f)' %(auc(recall_max,precision_max)))
plt.legend(loc = "lower right")
plt.tight_layout()
plt.show()
# Out:
# Presicion - Recall auc on validation data average score predictions: 0.357793626921145
# -----------------------------------------------------
# Presicion - Recall auc on validation data maximum score predictions: 0.4109647309705736
# -----------------------------------------------------

# %%
AVG_LIST_PREDICTIONS_VAL = [round(x) for x in AVG_LIST_PREDICTIONS_VAL]
print("CLASSIFICATION REPORT for AVERAGE SCORE PREDICTIONS")
print(classification_report(y_val_labels,AVG_LIST_PREDICTIONS_VAL))
# Out:
# CLASSIFICATION REPORT for AVERAGE SCORE PREDICTIONS
#               precision    recall  f1-score   support
#
#          0.0       0.73      0.91      0.81        33
#          1.0       0.40      0.15      0.22        13
#
#     accuracy                           0.70        46
#    macro avg       0.57      0.53      0.52        46
# weighted avg       0.64      0.70      0.64        46

# %%
MAX_LIST_PREDICTIONS_VAL = [round(x) for x in MAX_LIST_PREDICTIONS_VAL]
print("CLASSIFICATION REPORT for MAXIMUM SCORE PREDICTIONS")
print(classification_report(y_val_labels,MAX_LIST_PREDICTIONS_VAL))
# Out:
# CLASSIFICATION REPORT for MAXIMUM SCORE PREDICTIONS
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00        33
#          1.0       0.28      1.00      0.44        13
#
#     accuracy                           0.28        46
#    macro avg       0.14      0.50      0.22        46
# weighted avg       0.08      0.28      0.12        46
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# **SAVING THE MODEL WEIGHTS AND PREDICTIONS**

# %%
import pandas as pd
model.save('fold3_efficientnet_500.h5')#saving the model 
# !cp fold3_efficientnet_500.h5 "drive/My Drive/"
