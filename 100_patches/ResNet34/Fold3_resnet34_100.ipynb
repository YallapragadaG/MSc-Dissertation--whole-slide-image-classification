# %%
#loading the dataset and extracting from the zip file
# !unzip drive/My\ Drive/fold3_100.zip
#installing relevent modules for resnet34 model
# !pip install git+https://github.com/qubvel/classification_models.git
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: fold3_100/Train/Epithelioid/TCGA-3H-AB3O-01A-01-TS1.9EA61969-6557-4193-B2F9-EFC8B5564976.svs/30124-07088.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-3H-AB3O-01A-01-TS1.9EA61969-6557-4193-B2F9-EFC8B5564976.svs/23036-11518.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-3H-AB3O-01A-01-TS1.9EA61969-6557-4193-B2F9-EFC8B5564976.svs/42528-21264.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-3H-AB3O-01A-01-TS1.9EA61969-6557-4193-B2F9-EFC8B5564976.svs/71766-08860.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-3H-AB3O-01A-01-TS1.9EA61969-6557-4193-B2F9-EFC8B5564976.svs/73538-11518.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-3H-AB3O-01A-01-TS1.9EA61969-6557-4193-B2F9-EFC8B5564976.svs/35440-23036.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-3H-AB3O-01A-01-TS1.9EA61969-6557-4193-B2F9-EFC8B5564976.svs/34554-15062.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-3H-AB3O-01A-01-TS1.9EA61969-6557-4193-B2F9-EFC8B5564976.svs/20378-08860.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-3H-AB3O-01A-01-TS1.9EA61969-6557-4193-B2F9-EFC8B5564976.svs/22150-03544.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-3H-AB3O-01A-01-TS1.9EA61969-6557-4193-B2F9-EFC8B5564976.svs/37212-24808.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-3H-AB3O-01A-01-TS1.9EA61969-6557-4193-B2F9-EFC8B5564976.svs/32782-19492.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-3H-AB3O-01A-01-TS1.9EA61969-6557-4193-B2F9-EFC8B5564976.svs/64678-12404.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-3H-AB3O-01A-01-TS1.9EA61969-6557-4193-B2F9-EFC8B5564976.svs/15948-04430.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-3H-AB3O-01A-01-TS1.9EA61969-6557-4193-B2F9-EFC8B5564976.svs/85056-07088.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-3H-AB3O-01A-01-TS1.9EA61969-6557-4193-B2F9-EFC8B5564976.svs/15948-05316.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-3H-AB3O-01A-01-TS1.9EA61969-6557-4193-B2F9-EFC8B5564976.svs/92144-27466.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-3H-AB3O-01A-01-TS1.9EA61969-6557-4193-B2F9-EFC8B5564976.svs/09746-13290.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-3H-AB3O-01A-01-TS1.9EA61969-6557-4193-B2F9-EFC8B5564976.svs/80626-09746.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-3H-AB3O-01A-01-TS1.9EA61969-6557-4193-B2F9-EFC8B5564976.svs/95688-21264.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-3H-AB3O-01A-01-TS1.9EA61969-6557-4193-B2F9-EFC8B5564976.svs/38098-16834.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-3H-AB3O-01A-01-TS1.9EA61969-6557-4193-B2F9-EFC8B5564976.svs/31010-07974.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-3H-AB3O-01A-01-TS1.9EA61969-6557-4193-B2F9-EFC8B5564976.svs/75310-04430.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-3H-AB3O-01A-01-TS1.9EA61969-6557-4193-B2F9-EFC8B5564976.svs/86828-09746.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-3H-AB3O-01A-01-TS1.9EA61969-6557-4193-B2F9-EFC8B5564976.svs/26580-14176.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-3H-AB3O-01A-01-TS1.9EA61969-6557-4193-B2F9-EFC8B5564976.svs/69108-15062.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-3H-AB3O-01A-01-TS1.9EA61969-6557-4193-B2F9-EFC8B5564976.svs/94802-24808.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-3H-AB3O-01A-01-TS1.9EA61969-6557-4193-B2F9-EFC8B5564976.svs/76196-05316.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-3H-AB3O-01A-01-TS1.9EA61969-6557-4193-B2F9-EFC8B5564976.svs/33668-09746.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-3H-AB3O-01A-01-TS1.9EA61969-6557-4193-B2F9-EFC8B5564976.svs/72652-07088.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-3H-AB3O-01A-01-TS1.9EA61969-6557-4193-B2F9-EFC8B5564976.svs/17720-08860.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-3H-AB3O-01A-01-TS1.9EA61969-6557-4193-B2F9-EFC8B5564976.svs/74424-09746.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-3H-AB3O-01A-01-TS1.9EA61969-6557-4193-B2F9-EFC8B5564976.svs/86828-11518.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-3H-AB3O-01A-01-TS1.9EA61969-6557-4193-B2F9-EFC8B5564976.svs/67336-08860.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-3H-AB3O-01A-01-TS1.9EA61969-6557-4193-B2F9-EFC8B5564976.svs/11518-13290.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-3H-AB3O-01A-01-TS1.9EA61969-6557-4193-B2F9-EFC8B5564976.svs/35440-18606.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-3H-AB3O-01A-01-TS1.9EA61969-6557-4193-B2F9-EFC8B5564976.svs/23922-06202.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-3H-AB3O-01A-01-TS1.9EA61969-6557-4193-B2F9-EFC8B5564976.svs/78854-07974.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-3H-AB3O-01A-01-TS1.9EA61969-6557-4193-B2F9-EFC8B5564976.svs/36326-21264.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-3H-AB3O-01A-01-TS1.9EA61969-6557-4193-B2F9-EFC8B5564976.svs/32782-12404.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/07088-22150.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/28352-31010.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/09746-20378.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/09746-21264.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/26580-31896.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/32782-31010.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/20378-19492.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/23036-37212.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/26580-32782.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/07088-29238.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/30124-35440.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/17720-13290.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/63792-07088.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/15062-13290.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/33668-41642.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/40756-23922.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/34554-39870.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/53160-23036.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/17720-35440.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/27466-30124.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/31896-14176.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/07088-23922.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/38098-32782.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/13290-09746.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/38984-16834.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/35440-23922.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/19492-31896.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/34554-23036.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/18606-19492.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/26580-36326.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/24808-35440.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/23922-21264.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/43414-24808.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/10632-21264.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/41642-14176.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/14176-30124.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/44300-31896.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/16834-24808.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/09746-26580.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/11518-32782.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/38984-23036.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/16834-15948.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/40756-31010.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/50502-17720.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/53160-18606.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/40756-30124.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/43414-19492.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/59362-16834.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/23036-34554.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/52274-15948.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/12404-25694.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/45186-18606.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/29238-29238.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/32782-15062.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/24808-33668.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/31896-27466.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/43414-29238.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/30124-31896.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/39870-36326.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/11518-18606.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/17720-29238.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/44300-18606.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/38098-40756.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/42528-20378.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/51388-20378.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/30124-15062.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/16834-34554.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/21264-22150.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/30124-21264.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/51388-23922.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/18606-34554.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/38098-35440.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/17720-20378.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/20378-31010.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/38098-38984.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/28352-14176.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/13290-22150.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/38098-23036.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/23036-23036.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/21264-10632.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/23036-16834.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/15948-34554.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/21264-31010.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/12404-32782.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/55818-18606.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/39870-28352.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/17720-10632.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/27466-11518.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/30124-28352.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/23922-18606.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/38098-33668.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/23922-33668.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/38098-18606.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/62020-08860.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/16834-36326.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/07088-18606.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/23922-17720.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/28352-39870.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/10632-17720.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AF-01Z-00-DX1.B3F310A9-EA42-4B82-BC54-80839B324008.svs/30124-27466.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/13410-62580.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/52746-56322.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/63474-39336.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/47382-01788.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/73308-65262.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/57216-47382.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/43806-56322.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/79566-26820.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/09834-59004.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/18774-57216.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/22350-33972.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/33078-51852.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/68838-37548.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/61686-53640.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/12516-29502.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/77778-64368.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/10728-58110.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/46488-66156.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/25032-49170.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/103704-33972.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/15198-35760.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/15198-38442.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/97446-59004.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/68838-36654.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/100128-48276.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/94764-39336.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/37548-16986.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/42912-29502.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/50958-65262.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/85824-39336.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/10728-38442.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/24138-50064.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/09834-62580.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/16986-41124.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/91188-66156.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/10728-30396.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/49170-16986.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/08940-42018.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/38442-14304.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/13410-33972.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/08046-54534.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/39336-14304.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/61686-37548.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/104598-33078.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/87612-44700.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/46488-24138.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/30396-58110.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/52746-16986.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/53640-15198.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/83142-44700.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/95658-56322.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/93870-42912.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/32184-25926.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/28608-58110.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/41124-23244.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/20562-73308.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/80460-52746.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/47382-06258.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/109068-37548.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/46488-02682.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/97446-38442.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/99234-34866.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/75096-30396.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/96552-64368.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/74202-67944.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/17880-35760.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/96552-42018.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/16092-66156.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/65262-42912.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/38442-46488.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/15198-33972.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/66156-43806.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/76884-29502.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/14304-39336.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/27714-46488.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/85824-69732.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/13410-67050.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/14304-54534.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/53640-57216.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/16092-50958.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/16092-62580.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/109962-38442.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/94764-36654.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/79566-41124.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/74202-33972.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/71520-67050.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/57216-65262.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/90294-52746.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/88506-30396.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/89400-54534.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/18774-74202.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/33078-28608.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/37548-41124.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/73308-29502.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/40230-22350.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/17880-58110.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/16092-42912.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/48276-30396.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/76884-73308.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-SH-A7BC-01Z-00-DX1.FFC2EAE3-6C71-4702-9CC1-1C2471149E9A.svs/59898-50958.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/41642-12404.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/24808-25694.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/08860-31896.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/26580-31896.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/38098-22150.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/30124-23036.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/53160-11518.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/20378-19492.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/11518-26580.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/09746-32782.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/42528-15948.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/14176-37212.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/09746-31896.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/17720-40756.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/11518-31010.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/25694-24808.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/46072-15062.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/12404-16834.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/31010-10632.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/18606-19492.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/44300-15062.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/41642-14176.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/44300-21264.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/12404-35440.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/51388-14176.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/12404-24808.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/38984-23036.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/30124-14176.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/08860-34554.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/32782-22150.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/21264-16834.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/15948-19492.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/12404-39870.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/09746-27466.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/26580-30124.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/25694-33668.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/28352-31896.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/52274-07974.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/16834-25694.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/49616-16834.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/22150-37212.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/10632-26580.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/50502-06202.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/08860-27466.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/45186-18606.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/48730-20378.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/25694-18606.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/29238-14176.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/23922-13290.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/14176-25694.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/10632-25694.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/13290-31896.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/15948-32782.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/27466-18606.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/09746-24808.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/15948-31896.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/42528-21264.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/43414-22150.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/26580-13290.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/35440-23036.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/14176-38984.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/16834-41642.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/07974-23036.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/17720-20378.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/25694-23922.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/39870-20378.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/11518-16834.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/21264-21264.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/38098-23036.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/43414-15062.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/47844-19492.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/24808-23922.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/17720-42528.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/07088-23036.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/14176-24808.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/48730-14176.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/47844-18606.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/46958-09746.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/40756-18606.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/21264-31010.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/24808-30124.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/44300-15948.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/40756-14176.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/27466-24808.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/31010-23036.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/11518-35440.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/20378-20378.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/15062-31010.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/40756-17720.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/08860-33668.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/15062-34554.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/35440-18606.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/11518-25694.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/11518-40756.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/30124-28352.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/10632-38098.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/38098-18606.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/23922-14176.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/36326-21264.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A8AS-01Z-00-DX1.4278D910-79C3-44AB-A2A0-5B7CE54D64CB.svs/14176-38098.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/18606-03544.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/32782-08860.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/21264-25694.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/40756-42528.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/19492-04430.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/30124-15948.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/51388-39870.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/17720-25694.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/16834-17720.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/37212-23922.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/37212-32782.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/46072-21264.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/35440-42528.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/50502-12404.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/13290-09746.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/38984-16834.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/23922-07088.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/26580-04430.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/44300-08860.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/41642-40756.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/47844-26580.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/40756-37212.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/46072-31896.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/24808-24808.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/25694-16834.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/07974-10632.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/50502-16834.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/39870-51388.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/23922-08860.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/22150-23922.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/48730-29238.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/16834-24808.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/06202-14176.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/38984-38984.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/51388-38098.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/05316-13290.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/20378-07974.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/23036-08860.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/46072-28352.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/12404-11518.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/40756-41642.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/46072-45186.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/41642-51388.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/26580-08860.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/51388-16834.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/38984-25694.jpg
#   inflating: fold3_100/Train/Epithelioid/TCGA-TS-A7P6-01Z-00-DX1.0C2B22D5-27C7-4A7E-80B3-F2E7CC26CA01.svs/28352-15062.jpg
# ...
#   inflating: fold3_100/Validation/Epithelioid/TCGA-SH-A9CT-01Z-00-DX1.B89F48C7-DB0F-4D4F-8731-A59AC2511F7A.svs/05316-23922.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-SH-A9CT-01Z-00-DX1.B89F48C7-DB0F-4D4F-8731-A59AC2511F7A.svs/78854-35440.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-SH-A9CT-01Z-00-DX1.B89F48C7-DB0F-4D4F-8731-A59AC2511F7A.svs/28352-38984.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-SH-A9CT-01Z-00-DX1.B89F48C7-DB0F-4D4F-8731-A59AC2511F7A.svs/44300-25694.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-SH-A9CT-01Z-00-DX1.B89F48C7-DB0F-4D4F-8731-A59AC2511F7A.svs/26580-73538.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-SH-A9CT-01Z-00-DX1.B89F48C7-DB0F-4D4F-8731-A59AC2511F7A.svs/20378-36326.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-SH-A9CT-01Z-00-DX1.B89F48C7-DB0F-4D4F-8731-A59AC2511F7A.svs/42528-57590.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-SH-A9CT-01Z-00-DX1.B89F48C7-DB0F-4D4F-8731-A59AC2511F7A.svs/30124-57590.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-SH-A9CT-01Z-00-DX1.B89F48C7-DB0F-4D4F-8731-A59AC2511F7A.svs/83284-36326.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-SH-A9CT-01Z-00-DX1.B89F48C7-DB0F-4D4F-8731-A59AC2511F7A.svs/60248-31010.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-SH-A9CT-01Z-00-DX1.B89F48C7-DB0F-4D4F-8731-A59AC2511F7A.svs/75310-50502.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/37254-72734.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/48785-73621.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/22175-66525.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/49672-83378.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/47898-31932.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/39915-31932.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/15966-57655.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/54994-78056.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/10644-45237.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/41689-82491.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/23062-37254.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/42576-73621.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/30158-35480.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/40802-49672.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/16853-42576.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/58542-16853.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/49672-76282.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/60316-15079.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/47011-81604.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/39915-51446.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/68299-57655.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/60316-16853.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/46124-76282.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/46124-44350.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/59429-23949.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/23949-00000.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/38141-51446.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/50559-58542.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/53220-57655.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/46124-79830.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/40802-86926.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/39028-72734.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/47898-45237.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/37254-86039.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/57655-15079.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/33706-39915.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/54107-70073.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/51446-60316.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/45237-68299.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/20401-37254.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/56768-40802.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/65638-52333.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/52333-32819.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/50559-79830.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/22175-37254.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/47011-51446.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/61203-23949.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/28384-76282.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/54994-78943.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/37254-18627.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/15079-41689.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/47011-72734.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/54107-24836.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/20401-50559.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/23062-39028.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/23062-69186.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/09757-60316.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/51446-43463.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/52333-10644.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/18627-34593.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/41689-72734.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/12418-36367.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/59429-28384.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/55881-16853.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/44350-79830.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/39028-54107.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/46124-69186.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/45237-78056.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/51446-11531.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/47011-62090.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/51446-61203.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/53220-31045.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/47898-72734.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/21288-62090.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/41689-62977.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/53220-72734.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/51446-76282.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/62090-23949.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/39915-52333.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/39028-57655.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/07096-35480.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/44350-84265.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/58542-29271.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/51446-80717.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/22175-39028.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/14192-46124.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/47011-55881.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/51446-32819.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/40802-54994.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/09757-31932.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/40802-23062.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/29271-36367.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/39028-33706.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/39915-56768.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/53220-11531.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/27497-36367.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/33706-39028.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/13305-39915.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/16853-43463.jpg
#   inflating: fold3_100/Validation/Epithelioid/TCGA-UT-A88C-01Z-00-DX3.A761E40B-50C2-4157-BE06-52095FD4FAF6.svs/48785-62090.jpg
# Collecting git+https://github.com/qubvel/classification_models.git
#   Cloning https://github.com/qubvel/classification_models.git to /tmp/pip-req-build-v3x0_o4g
#   Running command git clone -q https://github.com/qubvel/classification_models.git /tmp/pip-req-build-v3x0_o4g
#   Running command git submodule update --init --recursive -q
# Collecting keras_applications<=1.0.8,>=1.0.7
#   Downloading https://files.pythonhosted.org/packages/71/e3/19762fdfc62877ae9102edf6342d71b28fbfd9dea3d2f96a882ce099b03f/Keras_Applications-1.0.8-py3-none-any.whl (50kB)
#      |████████████████████████████████| 51kB 2.6MB/s
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras_applications<=1.0.8,>=1.0.7->image-classifiers==1.0.0) (1.18.5)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras_applications<=1.0.8,>=1.0.7->image-classifiers==1.0.0) (2.10.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from h5py->keras_applications<=1.0.8,>=1.0.7->image-classifiers==1.0.0) (1.15.0)
# Building wheels for collected packages: image-classifiers
#   Building wheel for image-classifiers (setup.py) ... done
#   Created wheel for image-classifiers: filename=image_classifiers-1.0.0-cp36-none-any.whl size=20032 sha256=c3040a6a9d6a2464ee3991ffe40f177e72192af451050356fd0f84e1192f3c6a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-3cqeosfm/wheels/de/2b/fd/29a6d33edb8c28bc7d94e95ea1d39c9a218ac500a3cfb1b197
# Successfully built image-classifiers
# Installing collected packages: keras-applications, image-classifiers
# Successfully installed image-classifiers-1.0.0 keras-applications-1.0.8

# %%
import keras
import numpy as np
from keras.models import Sequential
from keras.layers.convolutional import Convolution2D
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D,AveragePooling2D
from keras.layers.advanced_activations import LeakyReLU
from keras.callbacks import EarlyStopping,ModelCheckpoint
from keras.models import load_model
from keras.layers.normalization import BatchNormalization
from classification_models.keras import Classifiers
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import KFold, StratifiedKFold
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve,roc_auc_score,precision_recall_curve,auc
from sklearn.metrics import average_precision_score
import tensorflow as tf
from sklearn.utils import class_weight
from keras.callbacks import EarlyStopping
from keras.preprocessing import image
import os
import glob
from fnmatch import fnmatch

# !pip install -U -q PyDrive
# from pydrive.auth import GoogleAuth
# from pydrive.drive import GoogleDrive 
# from google.colab import auth 
# from oauth2client.client import GoogleCredentials

# auth.authenticate_user()
# gauth = GoogleAuth()
# gauth.credentials = GoogleCredentials.get_application_default()                       
# drive = GoogleDrive(gauth)

# %%
train_path = "fold3_100/Train"
val_path = "fold3_100/Validation"
test_path ="fold3_100/Test"

batch_size = 64

loss_function ='categorical_crossentropy'
patience = 10
epoch = 50
final_activation ='softmax'
file_pattern = "*.jpg"
folder_pattern = "*TCGA-*"

Resnet34_model,preprocess_input = Classifiers.get('resnet34')
base_resnet34model = Resnet34_model(input_shape=(224,224,3), weights='imagenet', include_top=False)
base_resnet34model.summary()

#reading train and validation data
data_generator = ImageDataGenerator(rescale = 1./255,preprocessing_function=  preprocess_input)
#loop and iterating through train images
train_data_generator = data_generator.flow_from_directory(train_path,class_mode ='categorical',batch_size = batch_size,target_size = (224,224),shuffle =True)
#iterating through images of validation set
val_data_generator = data_generator.flow_from_directory(val_path,class_mode ='categorical',batch_size = batch_size,target_size = (224,224),shuffle = True)
#class wight balance

#class wight balance
# classes = train_data_generator.classes
class_weights_list = class_weight.compute_class_weight('balanced',np.unique(train_data_generator.classes),train_data_generator.classes)
weights = dict(zip(np.unique(train_data_generator.classes),class_weights_list))
print("weights ratio to make the dataset balanced: ",weights)

print("class Indices of train generator :",train_data_generator.class_indices)
print("class Indices of validation generator :",val_data_generator.class_indices)
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# data (InputLayer)               [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# bn_data (BatchNormalization)    (None, 224, 224, 3)  9           data[0][0]
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 230, 230, 3)  0           bn_data[0][0]
# __________________________________________________________________________________________________
# conv0 (Conv2D)                  (None, 112, 112, 64) 9408        zero_padding2d[0][0]
# __________________________________________________________________________________________________
# bn0 (BatchNormalization)        (None, 112, 112, 64) 256         conv0[0][0]
# __________________________________________________________________________________________________
# relu0 (Activation)              (None, 112, 112, 64) 0           bn0[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 114, 114, 64) 0           relu0[0][0]
# __________________________________________________________________________________________________
# pooling0 (MaxPooling2D)         (None, 56, 56, 64)   0           zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_bn1 (BatchNormaliz (None, 56, 56, 64)   256         pooling0[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_relu1 (Activation) (None, 56, 56, 64)   0           stage1_unit1_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_2 (ZeroPadding2D (None, 58, 58, 64)   0           stage1_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_conv1 (Conv2D)     (None, 56, 56, 64)   36864       zero_padding2d_2[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_bn2 (BatchNormaliz (None, 56, 56, 64)   256         stage1_unit1_conv1[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_relu2 (Activation) (None, 56, 56, 64)   0           stage1_unit1_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_3 (ZeroPadding2D (None, 58, 58, 64)   0           stage1_unit1_relu2[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_conv2 (Conv2D)     (None, 56, 56, 64)   36864       zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_sc (Conv2D)        (None, 56, 56, 64)   4096        stage1_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 56, 56, 64)   0           stage1_unit1_conv2[0][0]
#                                                                  stage1_unit1_sc[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_bn1 (BatchNormaliz (None, 56, 56, 64)   256         add[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_relu1 (Activation) (None, 56, 56, 64)   0           stage1_unit2_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_4 (ZeroPadding2D (None, 58, 58, 64)   0           stage1_unit2_relu1[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_conv1 (Conv2D)     (None, 56, 56, 64)   36864       zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_bn2 (BatchNormaliz (None, 56, 56, 64)   256         stage1_unit2_conv1[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_relu2 (Activation) (None, 56, 56, 64)   0           stage1_unit2_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_5 (ZeroPadding2D (None, 58, 58, 64)   0           stage1_unit2_relu2[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_conv2 (Conv2D)     (None, 56, 56, 64)   36864       zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 56, 56, 64)   0           stage1_unit2_conv2[0][0]
#                                                                  add[0][0]
# __________________________________________________________________________________________________
# stage1_unit3_bn1 (BatchNormaliz (None, 56, 56, 64)   256         add_1[0][0]
# __________________________________________________________________________________________________
# stage1_unit3_relu1 (Activation) (None, 56, 56, 64)   0           stage1_unit3_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_6 (ZeroPadding2D (None, 58, 58, 64)   0           stage1_unit3_relu1[0][0]
# __________________________________________________________________________________________________
# stage1_unit3_conv1 (Conv2D)     (None, 56, 56, 64)   36864       zero_padding2d_6[0][0]
# __________________________________________________________________________________________________
# stage1_unit3_bn2 (BatchNormaliz (None, 56, 56, 64)   256         stage1_unit3_conv1[0][0]
# __________________________________________________________________________________________________
# stage1_unit3_relu2 (Activation) (None, 56, 56, 64)   0           stage1_unit3_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_7 (ZeroPadding2D (None, 58, 58, 64)   0           stage1_unit3_relu2[0][0]
# __________________________________________________________________________________________________
# stage1_unit3_conv2 (Conv2D)     (None, 56, 56, 64)   36864       zero_padding2d_7[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 56, 56, 64)   0           stage1_unit3_conv2[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_bn1 (BatchNormaliz (None, 56, 56, 64)   256         add_2[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_relu1 (Activation) (None, 56, 56, 64)   0           stage2_unit1_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_8 (ZeroPadding2D (None, 58, 58, 64)   0           stage2_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_conv1 (Conv2D)     (None, 28, 28, 128)  73728       zero_padding2d_8[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_bn2 (BatchNormaliz (None, 28, 28, 128)  512         stage2_unit1_conv1[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_relu2 (Activation) (None, 28, 28, 128)  0           stage2_unit1_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_9 (ZeroPadding2D (None, 30, 30, 128)  0           stage2_unit1_relu2[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_conv2 (Conv2D)     (None, 28, 28, 128)  147456      zero_padding2d_9[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_sc (Conv2D)        (None, 28, 28, 128)  8192        stage2_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 28, 28, 128)  0           stage2_unit1_conv2[0][0]
#                                                                  stage2_unit1_sc[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_bn1 (BatchNormaliz (None, 28, 28, 128)  512         add_3[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_relu1 (Activation) (None, 28, 28, 128)  0           stage2_unit2_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_10 (ZeroPadding2 (None, 30, 30, 128)  0           stage2_unit2_relu1[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_conv1 (Conv2D)     (None, 28, 28, 128)  147456      zero_padding2d_10[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_bn2 (BatchNormaliz (None, 28, 28, 128)  512         stage2_unit2_conv1[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_relu2 (Activation) (None, 28, 28, 128)  0           stage2_unit2_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_11 (ZeroPadding2 (None, 30, 30, 128)  0           stage2_unit2_relu2[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_conv2 (Conv2D)     (None, 28, 28, 128)  147456      zero_padding2d_11[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 28, 28, 128)  0           stage2_unit2_conv2[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# stage2_unit3_bn1 (BatchNormaliz (None, 28, 28, 128)  512         add_4[0][0]
# __________________________________________________________________________________________________
# stage2_unit3_relu1 (Activation) (None, 28, 28, 128)  0           stage2_unit3_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_12 (ZeroPadding2 (None, 30, 30, 128)  0           stage2_unit3_relu1[0][0]
# __________________________________________________________________________________________________
# stage2_unit3_conv1 (Conv2D)     (None, 28, 28, 128)  147456      zero_padding2d_12[0][0]
# __________________________________________________________________________________________________
# stage2_unit3_bn2 (BatchNormaliz (None, 28, 28, 128)  512         stage2_unit3_conv1[0][0]
# __________________________________________________________________________________________________
# stage2_unit3_relu2 (Activation) (None, 28, 28, 128)  0           stage2_unit3_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_13 (ZeroPadding2 (None, 30, 30, 128)  0           stage2_unit3_relu2[0][0]
# __________________________________________________________________________________________________
# stage2_unit3_conv2 (Conv2D)     (None, 28, 28, 128)  147456      zero_padding2d_13[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 28, 28, 128)  0           stage2_unit3_conv2[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# stage2_unit4_bn1 (BatchNormaliz (None, 28, 28, 128)  512         add_5[0][0]
# __________________________________________________________________________________________________
# stage2_unit4_relu1 (Activation) (None, 28, 28, 128)  0           stage2_unit4_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_14 (ZeroPadding2 (None, 30, 30, 128)  0           stage2_unit4_relu1[0][0]
# __________________________________________________________________________________________________
# stage2_unit4_conv1 (Conv2D)     (None, 28, 28, 128)  147456      zero_padding2d_14[0][0]
# __________________________________________________________________________________________________
# stage2_unit4_bn2 (BatchNormaliz (None, 28, 28, 128)  512         stage2_unit4_conv1[0][0]
# __________________________________________________________________________________________________
# stage2_unit4_relu2 (Activation) (None, 28, 28, 128)  0           stage2_unit4_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_15 (ZeroPadding2 (None, 30, 30, 128)  0           stage2_unit4_relu2[0][0]
# __________________________________________________________________________________________________
# stage2_unit4_conv2 (Conv2D)     (None, 28, 28, 128)  147456      zero_padding2d_15[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 28, 28, 128)  0           stage2_unit4_conv2[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_bn1 (BatchNormaliz (None, 28, 28, 128)  512         add_6[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_relu1 (Activation) (None, 28, 28, 128)  0           stage3_unit1_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_16 (ZeroPadding2 (None, 30, 30, 128)  0           stage3_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_conv1 (Conv2D)     (None, 14, 14, 256)  294912      zero_padding2d_16[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_bn2 (BatchNormaliz (None, 14, 14, 256)  1024        stage3_unit1_conv1[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_relu2 (Activation) (None, 14, 14, 256)  0           stage3_unit1_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_17 (ZeroPadding2 (None, 16, 16, 256)  0           stage3_unit1_relu2[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_conv2 (Conv2D)     (None, 14, 14, 256)  589824      zero_padding2d_17[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_sc (Conv2D)        (None, 14, 14, 256)  32768       stage3_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 14, 14, 256)  0           stage3_unit1_conv2[0][0]
#                                                                  stage3_unit1_sc[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_bn1 (BatchNormaliz (None, 14, 14, 256)  1024        add_7[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_relu1 (Activation) (None, 14, 14, 256)  0           stage3_unit2_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_18 (ZeroPadding2 (None, 16, 16, 256)  0           stage3_unit2_relu1[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_conv1 (Conv2D)     (None, 14, 14, 256)  589824      zero_padding2d_18[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_bn2 (BatchNormaliz (None, 14, 14, 256)  1024        stage3_unit2_conv1[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_relu2 (Activation) (None, 14, 14, 256)  0           stage3_unit2_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_19 (ZeroPadding2 (None, 16, 16, 256)  0           stage3_unit2_relu2[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_conv2 (Conv2D)     (None, 14, 14, 256)  589824      zero_padding2d_19[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 14, 14, 256)  0           stage3_unit2_conv2[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# stage3_unit3_bn1 (BatchNormaliz (None, 14, 14, 256)  1024        add_8[0][0]
# __________________________________________________________________________________________________
# stage3_unit3_relu1 (Activation) (None, 14, 14, 256)  0           stage3_unit3_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_20 (ZeroPadding2 (None, 16, 16, 256)  0           stage3_unit3_relu1[0][0]
# __________________________________________________________________________________________________
# stage3_unit3_conv1 (Conv2D)     (None, 14, 14, 256)  589824      zero_padding2d_20[0][0]
# __________________________________________________________________________________________________
# stage3_unit3_bn2 (BatchNormaliz (None, 14, 14, 256)  1024        stage3_unit3_conv1[0][0]
# __________________________________________________________________________________________________
# stage3_unit3_relu2 (Activation) (None, 14, 14, 256)  0           stage3_unit3_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_21 (ZeroPadding2 (None, 16, 16, 256)  0           stage3_unit3_relu2[0][0]
# __________________________________________________________________________________________________
# stage3_unit3_conv2 (Conv2D)     (None, 14, 14, 256)  589824      zero_padding2d_21[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 14, 14, 256)  0           stage3_unit3_conv2[0][0]
#                                                                  add_8[0][0]
# __________________________________________________________________________________________________
# stage3_unit4_bn1 (BatchNormaliz (None, 14, 14, 256)  1024        add_9[0][0]
# __________________________________________________________________________________________________
# stage3_unit4_relu1 (Activation) (None, 14, 14, 256)  0           stage3_unit4_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_22 (ZeroPadding2 (None, 16, 16, 256)  0           stage3_unit4_relu1[0][0]
# __________________________________________________________________________________________________
# stage3_unit4_conv1 (Conv2D)     (None, 14, 14, 256)  589824      zero_padding2d_22[0][0]
# __________________________________________________________________________________________________
# stage3_unit4_bn2 (BatchNormaliz (None, 14, 14, 256)  1024        stage3_unit4_conv1[0][0]
# __________________________________________________________________________________________________
# stage3_unit4_relu2 (Activation) (None, 14, 14, 256)  0           stage3_unit4_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_23 (ZeroPadding2 (None, 16, 16, 256)  0           stage3_unit4_relu2[0][0]
# __________________________________________________________________________________________________
# stage3_unit4_conv2 (Conv2D)     (None, 14, 14, 256)  589824      zero_padding2d_23[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 14, 14, 256)  0           stage3_unit4_conv2[0][0]
#                                                                  add_9[0][0]
# __________________________________________________________________________________________________
# stage3_unit5_bn1 (BatchNormaliz (None, 14, 14, 256)  1024        add_10[0][0]
# __________________________________________________________________________________________________
# stage3_unit5_relu1 (Activation) (None, 14, 14, 256)  0           stage3_unit5_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_24 (ZeroPadding2 (None, 16, 16, 256)  0           stage3_unit5_relu1[0][0]
# __________________________________________________________________________________________________
# stage3_unit5_conv1 (Conv2D)     (None, 14, 14, 256)  589824      zero_padding2d_24[0][0]
# __________________________________________________________________________________________________
# stage3_unit5_bn2 (BatchNormaliz (None, 14, 14, 256)  1024        stage3_unit5_conv1[0][0]
# __________________________________________________________________________________________________
# stage3_unit5_relu2 (Activation) (None, 14, 14, 256)  0           stage3_unit5_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_25 (ZeroPadding2 (None, 16, 16, 256)  0           stage3_unit5_relu2[0][0]
# __________________________________________________________________________________________________
# stage3_unit5_conv2 (Conv2D)     (None, 14, 14, 256)  589824      zero_padding2d_25[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 14, 14, 256)  0           stage3_unit5_conv2[0][0]
#                                                                  add_10[0][0]
# __________________________________________________________________________________________________
# stage3_unit6_bn1 (BatchNormaliz (None, 14, 14, 256)  1024        add_11[0][0]
# __________________________________________________________________________________________________
# stage3_unit6_relu1 (Activation) (None, 14, 14, 256)  0           stage3_unit6_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_26 (ZeroPadding2 (None, 16, 16, 256)  0           stage3_unit6_relu1[0][0]
# __________________________________________________________________________________________________
# stage3_unit6_conv1 (Conv2D)     (None, 14, 14, 256)  589824      zero_padding2d_26[0][0]
# __________________________________________________________________________________________________
# stage3_unit6_bn2 (BatchNormaliz (None, 14, 14, 256)  1024        stage3_unit6_conv1[0][0]
# __________________________________________________________________________________________________
# stage3_unit6_relu2 (Activation) (None, 14, 14, 256)  0           stage3_unit6_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_27 (ZeroPadding2 (None, 16, 16, 256)  0           stage3_unit6_relu2[0][0]
# __________________________________________________________________________________________________
# stage3_unit6_conv2 (Conv2D)     (None, 14, 14, 256)  589824      zero_padding2d_27[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 14, 14, 256)  0           stage3_unit6_conv2[0][0]
#                                                                  add_11[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_bn1 (BatchNormaliz (None, 14, 14, 256)  1024        add_12[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_relu1 (Activation) (None, 14, 14, 256)  0           stage4_unit1_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_28 (ZeroPadding2 (None, 16, 16, 256)  0           stage4_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_conv1 (Conv2D)     (None, 7, 7, 512)    1179648     zero_padding2d_28[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_bn2 (BatchNormaliz (None, 7, 7, 512)    2048        stage4_unit1_conv1[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_relu2 (Activation) (None, 7, 7, 512)    0           stage4_unit1_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_29 (ZeroPadding2 (None, 9, 9, 512)    0           stage4_unit1_relu2[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_conv2 (Conv2D)     (None, 7, 7, 512)    2359296     zero_padding2d_29[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_sc (Conv2D)        (None, 7, 7, 512)    131072      stage4_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 7, 7, 512)    0           stage4_unit1_conv2[0][0]
#                                                                  stage4_unit1_sc[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_bn1 (BatchNormaliz (None, 7, 7, 512)    2048        add_13[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_relu1 (Activation) (None, 7, 7, 512)    0           stage4_unit2_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_30 (ZeroPadding2 (None, 9, 9, 512)    0           stage4_unit2_relu1[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_conv1 (Conv2D)     (None, 7, 7, 512)    2359296     zero_padding2d_30[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_bn2 (BatchNormaliz (None, 7, 7, 512)    2048        stage4_unit2_conv1[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_relu2 (Activation) (None, 7, 7, 512)    0           stage4_unit2_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_31 (ZeroPadding2 (None, 9, 9, 512)    0           stage4_unit2_relu2[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_conv2 (Conv2D)     (None, 7, 7, 512)    2359296     zero_padding2d_31[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 7, 7, 512)    0           stage4_unit2_conv2[0][0]
#                                                                  add_13[0][0]
# __________________________________________________________________________________________________
# stage4_unit3_bn1 (BatchNormaliz (None, 7, 7, 512)    2048        add_14[0][0]
# __________________________________________________________________________________________________
# stage4_unit3_relu1 (Activation) (None, 7, 7, 512)    0           stage4_unit3_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_32 (ZeroPadding2 (None, 9, 9, 512)    0           stage4_unit3_relu1[0][0]
# __________________________________________________________________________________________________
# stage4_unit3_conv1 (Conv2D)     (None, 7, 7, 512)    2359296     zero_padding2d_32[0][0]
# __________________________________________________________________________________________________
# stage4_unit3_bn2 (BatchNormaliz (None, 7, 7, 512)    2048        stage4_unit3_conv1[0][0]
# __________________________________________________________________________________________________
# stage4_unit3_relu2 (Activation) (None, 7, 7, 512)    0           stage4_unit3_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_33 (ZeroPadding2 (None, 9, 9, 512)    0           stage4_unit3_relu2[0][0]
# __________________________________________________________________________________________________
# stage4_unit3_conv2 (Conv2D)     (None, 7, 7, 512)    2359296     zero_padding2d_33[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 7, 7, 512)    0           stage4_unit3_conv2[0][0]
#                                                                  add_14[0][0]
# __________________________________________________________________________________________________
# bn1 (BatchNormalization)        (None, 7, 7, 512)    2048        add_15[0][0]
# __________________________________________________________________________________________________
# relu1 (Activation)              (None, 7, 7, 512)    0           bn1[0][0]
# ==================================================================================================
# Total params: 21,302,473
# Trainable params: 21,287,107
# Non-trainable params: 15,366
# __________________________________________________________________________________________________
# Found 9170 images belonging to 2 classes.
# Found 4443 images belonging to 2 classes.
# weights ratio to make the dataset balanced:  {0: 0.6769526059353315, 1: 1.912807676261994}
# class Indices of train generator : {'Epithelioid': 0, 'Nonepithelioid': 1}
# class Indices of validation generator : {'Epithelioid': 0, 'Nonepithelioid': 1}

# %%
def training_model(pretrained_model,final_activation):
    model = Sequential()
    model.add(pretrained_model) #pretrained model
    model.add(Flatten()) #creating a single 1-d vector
    model.add(Dense(2,activation=final_activation))#output layer with softmax activation function.
    return model

#this function takes the each patch in WSI then predicts the probability score
def pred_each_patch(path,name):
    y = image.load_img(os.path.join(path, name))
    img = image.img_to_array(y)
    y = np.expand_dims(img, axis = 0)
    y = preprocess_input(y)
    y /= 255
    y_pred = model.predict(y)
    return y_pred
        
def avg(predlist):
    average = sum(predlist)/len(predlist)
    return average

def extract_index_one_frmpred(prediction_list):               
    ypred = np.stack(prediction_list)#we are vertically stacking the predictions
    ypred = np.reshape(ypred, [len(prediction_list),2])#reshaping to 100,2 - np array
    for each in ypred:
    #after reshaping the predictions as we wanted, we are taking the index '1' to compute whole slide level AUC-ROC
        val = each[1]
        pred_prob_list.append(val)#appending all the values into a list - to compute average values of single WSI and maximum of single WSI.
        
    return pred_prob_list
    
def plt_history(history): 
    
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epochs')
    plt.legend(['train', 'validation'], loc='upper right')
    plt.tight_layout() 
    plt.show()
    return

def y_labels(path):
  if "Epithelioid" in path:
    y_test_labels.append(0.0)
  elif "Nonepithelioid" in path:
    y_test_labels.append(1.0) 
  return

def prediction_scores(y_test_labels,AVG_LIST_PREDICTIONS,MAX_LIST_PREDICTIONS):
  #AUC - ROC score
  false_pr_avg,true_pr_avg,threshold = roc_curve(y_test_labels,AVG_LIST_PREDICTIONS)
  roc_auc_avg = auc(false_pr_avg,true_pr_avg)
  print("AUC - ROC on Test data average prediction scores:",roc_auc_avg)
  print("-----------------------------------------------------")
  plt.plot(false_pr_avg,true_pr_avg,color='green',label='ROC curve on test data(area = %0.2f)' %(auc(false_pr_avg,true_pr_avg)))
  plt.plot([0, 1], [0, 1], color='navy', linestyle='--',label = 'Random')
  plt.xlabel("False positive rate")
  plt.ylabel("True positive rate")
  plt.title('ROC curve on Test data (area = %0.2f)' %(auc(false_pr_avg,true_pr_avg)))
  plt.legend(loc = "lower right")
  plt.tight_layout()
  plt.show()
  
  false_pr_max,true_pr_max,threshold = roc_curve(y_test_labels,MAX_LIST_PREDICTIONS)
  roc_auc_max = auc(false_pr_max,true_pr_max)
  print("AUC - ROC on Test data maximum prediction scores:",roc_auc_max)
  print("-----------------------------------------------------")
  plt.plot(false_pr_max,true_pr_max,color='magenta',label='ROC curve on test data(area = %0.2f)' %(auc(false_pr_max,true_pr_max)))
  plt.plot([0, 1], [0, 1], color='navy', linestyle='--',label = 'Random')
  plt.xlabel("False positive rate")
  plt.ylabel("True positive rate")
  plt.title('ROC curve on Test data (area = %0.2f)' %(auc(false_pr_max,true_pr_max)))
  plt.legend(loc = "lower right")
  plt.tight_layout()
  plt.show()
 

def pre_recall(y_test_labels,AVG_LIST_PREDICTIONS,MAX_LIST_PREDICTIONS):
  #presicion - recall curve
  precision, recall, threshold = precision_recall_curve(y_test_labels,AVG_LIST_PREDICTIONS)
  print("Presicion - Recall auc on test data average score predictions:",auc(recall,precision))
 
  print("-----------------------------------------------------")
  plt.plot(precision, recall,color='orange',label='PR curve (area = %0.2f)' %(auc(recall,precision)))
  plt.xlabel("Recall")
  plt.ylabel("Precision")
  plt.title('Presicion Recall curve on Test data (area = %0.2f)' %(auc(recall,precision)))
  plt.legend(loc = "lower right")
  plt.tight_layout()
  plt.show()

  precision_max, recall_max, threshold = precision_recall_curve(y_test_labels,MAX_LIST_PREDICTIONS)
  print("Presicion - Recall auc on test data maximum score predictions:",auc(recall_max,precision_max))
 
  print("-----------------------------------------------------")
  plt.plot(precision_max, recall_max,color='cyan',label='PR curve (area = %0.2f)' %(auc(recall_max,precision_max)))
  plt.xlabel("Recall")
  plt.ylabel("Precision")
  plt.title('Presicion Recall curve on Test data (area = %0.2f)' %(auc(recall_max,precision_max)))
  plt.legend(loc = "lower right")
  plt.tight_layout()
  plt.show()

# %%
from keras.models import load_model

model = training_model(base_resnet34model,final_activation)  

reduce_lr = keras.callbacks.ReduceLROnPlateau(monitor = 'val_loss',factor = 0.1,patience=3,verbose = 1)
# early stopping to prevent overfitting
es = EarlyStopping(monitor='val_loss',verbose=1, patience=patience)

opt_nadam = tf.keras.optimizers.Nadam(1e-4)#Adam with Nestrov momentum

model.compile(optimizer= opt_nadam, loss=loss_function,metrics = [tf.keras.metrics.AUC(),tf.keras.metrics.Precision(),tf.keras.metrics.Recall()])


#Initilaising the model
history = model.fit(train_data_generator, steps_per_epoch=len(train_data_generator.classes)//batch_size, validation_data=val_data_generator,epochs = epoch,class_weight = weights,callbacks =[es,reduce_lr],workers = 4)
    
plt_history(history)#model_loss_plot 

AVG_LIST_PREDICTIONS = []
MAX_LIST_PREDICTIONS = []
y_test_labels= []
print("Prediction on test using aggregation method")
for path, subdirs, files in os.walk(test_path): #iterating through folders of each WSI
    if(fnmatch(path,folder_pattern)):
        WSI_pred = list()
        pred_prob_list = list()
        # print("Iterating through all the patches in: ",os.path.basename(os.path.normpath(path)))
        y_labels(path)

        for name in files:
          if fnmatch(name, file_pattern):#iterating through each patch in all WSI image and computing probabilities
              prediction = pred_each_patch(path,name)
              WSI_pred.append(prediction)#this list contains probabilities of all patches in testset images

        #computing average and maximum prediction of each image - so that we can compute Whole slide level AUC - ROC than patch level
        predictions = extract_index_one_frmpred(WSI_pred)
        #This list contains average score of all 36 test set images
        AVG_LIST_PREDICTIONS.append(avg(predictions))
        MAX_LIST_PREDICTIONS.append(max(predictions))

prediction_scores(y_test_labels,AVG_LIST_PREDICTIONS,MAX_LIST_PREDICTIONS)
# Out:
# Epoch 1/50
# 143/143 [==============================] - 65s 451ms/step - loss: 0.8602 - auc: 0.7060 - precision: 0.6478 - recall: 0.6478 - val_loss: 1.5745 - val_auc: 0.6915 - val_precision: 0.6914 - val_recall: 0.6914
# Epoch 2/50
# 143/143 [==============================] - 64s 447ms/step - loss: 0.1273 - auc: 0.9907 - precision: 0.9504 - recall: 0.9504 - val_loss: 1.2319 - val_auc: 0.3079 - val_precision: 0.3086 - val_recall: 0.3086
# Epoch 3/50
# 143/143 [==============================] - 65s 453ms/step - loss: 0.0287 - auc: 0.9998 - precision: 0.9936 - recall: 0.9936 - val_loss: 1.1031 - val_auc: 0.2973 - val_precision: 0.3086 - val_recall: 0.3086
# Epoch 4/50
# 143/143 [==============================] - 65s 456ms/step - loss: 0.0080 - auc: 1.0000 - precision: 0.9990 - recall: 0.9990 - val_loss: 2.3339 - val_auc: 0.3197 - val_precision: 0.3086 - val_recall: 0.3086
# Epoch 5/50
# 143/143 [==============================] - 66s 460ms/step - loss: 0.0034 - auc: 1.0000 - precision: 0.9998 - recall: 0.9998 - val_loss: 3.0538 - val_auc: 0.3292 - val_precision: 0.3084 - val_recall: 0.3084
# Epoch 6/50
# 143/143 [==============================] - ETA: 0s - loss: 0.0023 - auc: 1.0000 - precision: 0.9999 - recall: 0.9999
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 143/143 [==============================] - 66s 462ms/step - loss: 0.0023 - auc: 1.0000 - precision: 0.9999 - recall: 0.9999 - val_loss: 2.6930 - val_auc: 0.3307 - val_precision: 0.3297 - val_recall: 0.3297
# Epoch 7/50
# 143/143 [==============================] - 66s 461ms/step - loss: 0.0013 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.2975 - val_auc: 0.3985 - val_precision: 0.4193 - val_recall: 0.4193
# Epoch 8/50
# 143/143 [==============================] - 66s 460ms/step - loss: 0.0012 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.5619 - val_auc: 0.6149 - val_precision: 0.5791 - val_recall: 0.5791
# Epoch 9/50
# 143/143 [==============================] - ETA: 0s - loss: 0.0012 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 143/143 [==============================] - 66s 461ms/step - loss: 0.0012 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.5191 - val_auc: 0.6945 - val_precision: 0.6462 - val_recall: 0.6462
# Epoch 10/50
# 143/143 [==============================] - 66s 461ms/step - loss: 0.0012 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.5054 - val_auc: 0.7140 - val_precision: 0.6628 - val_recall: 0.6628
# Epoch 11/50
# 143/143 [==============================] - 66s 463ms/step - loss: 0.0010 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.5024 - val_auc: 0.7189 - val_precision: 0.6680 - val_recall: 0.6680
# Epoch 12/50
# 143/143 [==============================] - ETA: 0s - loss: 0.0013 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
# 143/143 [==============================] - 66s 463ms/step - loss: 0.0013 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.4939 - val_auc: 0.7195 - val_precision: 0.6689 - val_recall: 0.6689
# Epoch 13/50
# 143/143 [==============================] - 66s 463ms/step - loss: 0.0011 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.4916 - val_auc: 0.7205 - val_precision: 0.6691 - val_recall: 0.6691
# Epoch 00013: early stopping
# Prediction on test using aggregation method
# AUC - ROC on Test data average prediction scores: 0.7242798353909465
# -----------------------------------------------------
# AUC - ROC on Test data maximum prediction scores: 0.5802469135802469
# -----------------------------------------------------

# %% [markdown]
# **Presicion recall curves**

# %%
pre_recall(y_test_labels,AVG_LIST_PREDICTIONS,MAX_LIST_PREDICTIONS)
# Out:
# Presicion - Recall auc on test data average score predictions: 0.4458469167708298
# -----------------------------------------------------
# Presicion - Recall auc on test data maximum score predictions: 0.26762248401893496
# -----------------------------------------------------

# %% [markdown]
# **Classification reports**

# %%
from sklearn.metrics import classification_report

AVG_LIST_PREDICTIONS = [round(x) for x in AVG_LIST_PREDICTIONS]
print("CLASSIFICATION REPORT for AVERAGE SCORE PREDICTIONS")
print(classification_report(y_test_labels,AVG_LIST_PREDICTIONS))
# Out:
# CLASSIFICATION REPORT for AVERAGE SCORE PREDICTIONS
#               precision    recall  f1-score   support
#
#          0.0       0.77      1.00      0.87        27
#          1.0       1.00      0.11      0.20         9
#
#     accuracy                           0.78        36
#    macro avg       0.89      0.56      0.54        36
# weighted avg       0.83      0.78      0.70        36

# %%
MAX_LIST_PREDICTIONS = [round(x) for x in MAX_LIST_PREDICTIONS]
print("CLASSIFICATION REPORT for MAX VALUE PREDICTIONS")
print(classification_report(y_test_labels,MAX_LIST_PREDICTIONS))
# Out:
# CLASSIFICATION REPORT for MAX VALUE PREDICTIONS
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00        27
#          1.0       0.25      1.00      0.40         9
#
#     accuracy                           0.25        36
#    macro avg       0.12      0.50      0.20        36
# weighted avg       0.06      0.25      0.10        36
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# **PREDICTIONS ON VALIDATION DATA USING AGGREGATION METHOD**

# %%
AVG_LIST_PREDICTIONS_VAL = []
MAX_LIST_PREDICTIONS_VAL = []
y_val_labels= []
print("Prediction on validation using aggregation method")
for path, subdirs, files in os.walk(val_path): #iterating through folders of each WSI
    if(fnmatch(path,folder_pattern)):
        WSI_pred = list()
        pred_prob_list = list()
        # print("Iterating through all the patches in: ",os.path.basename(os.path.normpath(path)))
        if "Epithelioid" in path:
          y_val_labels.append(0.0)
        elif "Nonepithelioid" in path:
          y_val_labels.append(1.0) 

        for name in files:
          if fnmatch(name, file_pattern):#iterating through each patch in all WSI image and computing probabilities
              prediction = pred_each_patch(path,name)
              WSI_pred.append(prediction)#this list contains probabilities of all patches in testset images

        #computing average and maximum prediction of each image - so that we can compute Whole slide level AUC - ROC than patch level
        predictions = extract_index_one_frmpred(WSI_pred)
        #This list contains average score of all 36 test set images
        AVG_LIST_PREDICTIONS_VAL.append(avg(predictions))
        MAX_LIST_PREDICTIONS_VAL.append(max(predictions))

false_pr_avg,true_pr_avg,threshold = roc_curve(y_val_labels,AVG_LIST_PREDICTIONS_VAL)
roc_auc_avg = auc(false_pr_avg,true_pr_avg)
print("AUC - ROC on validation data average prediction scores:",roc_auc_avg)
print("-----------------------------------------------------")
plt.plot(false_pr_avg,true_pr_avg,color='green',label='ROC curve on validation data(area = %0.2f)' %(auc(false_pr_avg,true_pr_avg)))
plt.plot([0, 1], [0, 1], color='navy', linestyle='--',label = 'Random')
plt.xlabel("False positive rate")
plt.ylabel("True positive rate")
plt.title('ROC curve on validation data (area = %0.2f)' %(auc(false_pr_avg,true_pr_avg)))
plt.legend(loc = "lower right")
plt.tight_layout()
plt.show()
  
false_pr_max,true_pr_max,threshold = roc_curve(y_val_labels,MAX_LIST_PREDICTIONS_VAL)
roc_auc_max = auc(false_pr_max,true_pr_max)
print("AUC - ROC on validation data maximum prediction scores:",roc_auc_max)
print("-----------------------------------------------------")
plt.plot(false_pr_max,true_pr_max,color='magenta',label='ROC curve on validation data(area = %0.2f)' %(auc(false_pr_max,true_pr_max)))
plt.plot([0, 1], [0, 1], color='navy', linestyle='--',label = 'Random')
plt.xlabel("False positive rate")
plt.ylabel("True positive rate")
plt.title('ROC curve on validation data (area = %0.2f)' %(auc(false_pr_max,true_pr_max)))
plt.legend(loc = "lower right")
plt.tight_layout()
plt.show()
# Out:
# Prediction on validation using aggregation method
# AUC - ROC on validation data average prediction scores: 0.6785714285714286
# -----------------------------------------------------
# AUC - ROC on validation data maximum prediction scores: 0.6350446428571428
# -----------------------------------------------------

# %%
#presicion - recall curve
precision, recall, threshold = precision_recall_curve(y_val_labels,AVG_LIST_PREDICTIONS_VAL)
print("Presicion - Recall auc on validation data average score predictions:",auc(recall,precision))
 
print("-----------------------------------------------------")
plt.plot(precision, recall,color='red',label='PR curve (area = %0.2f)' %(auc(recall,precision)))
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title('Presicion Recall curve on validation data (area = %0.2f)' %(auc(recall,precision)))
plt.legend(loc = "lower right")
plt.tight_layout()
plt.show()

precision_max, recall_max, threshold = precision_recall_curve(y_val_labels,MAX_LIST_PREDICTIONS_VAL)
print("Presicion - Recall auc on validation data maximum score predictions:",auc(recall_max,precision_max))
print("-----------------------------------------------------")
plt.plot(precision_max, recall_max,color='blue',label='PR curve (area = %0.2f)' %(auc(recall_max,precision_max)))
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title('Presicion Recall curve on validation data (area = %0.2f)' %(auc(recall_max,precision_max)))
plt.legend(loc = "lower right")
plt.tight_layout()
plt.show()
# Out:
# Presicion - Recall auc on validation data average score predictions: 0.5087259673548329
# -----------------------------------------------------
# Presicion - Recall auc on validation data maximum score predictions: 0.3849708215953217
# -----------------------------------------------------

# %%
AVG_LIST_PREDICTIONS_VAL = [round(x) for x in AVG_LIST_PREDICTIONS_VAL]
print("CLASSIFICATION REPORT for AVERAGE SCORE PREDICTIONS")
print(classification_report(y_val_labels,AVG_LIST_PREDICTIONS_VAL))
# Out:
# CLASSIFICATION REPORT for AVERAGE SCORE PREDICTIONS
#               precision    recall  f1-score   support
#
#          0.0       0.70      0.97      0.82        32
#          1.0       0.50      0.07      0.12        14
#
#     accuracy                           0.70        46
#    macro avg       0.60      0.52      0.47        46
# weighted avg       0.64      0.70      0.61        46

# %%
MAX_LIST_PREDICTIONS_VAL = [round(x) for x in MAX_LIST_PREDICTIONS_VAL]
print("CLASSIFICATION REPORT for MAXIMUM SCORE PREDICTIONS")
print(classification_report(y_val_labels,MAX_LIST_PREDICTIONS_VAL))
# Out:
# CLASSIFICATION REPORT for MAXIMUM SCORE PREDICTIONS
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00        32
#          1.0       0.30      1.00      0.47        14
#
#     accuracy                           0.30        46
#    macro avg       0.15      0.50      0.23        46
# weighted avg       0.09      0.30      0.14        46
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# **SAVING THE MODEL WEIGHTS AND PREDICTIONS**

# %%
import pandas as pd
model.save('fold3_resnet34_100.h5')#saving the model 
#saving the predictions
df = pd.DataFrame(list(zip(AVG_LIST_PREDICTIONS,MAX_LIST_PREDICTIONS,y_test_labels)),columns=['avg','max','actual'])
df.to_csv('FOLD3_100_res.csv',index = False,header = True)
df_val = pd.DataFrame(list(zip(AVG_LIST_PREDICTIONS_VAL,MAX_LIST_PREDICTIONS_VAL,y_val_labels)),columns=['avg','max','actual'])
df_val.to_csv('FOLD3_100_res34_val.csv',index = False,header = True)
# !cp FOLD3_100_res34_val.csv "drive/My Drive/"
# !cp FOLD3_100_res.csv "drive/My Drive/"
